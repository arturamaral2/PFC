# %%
import sys
import os
import gym
import torch
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
sys.path.append('ballbeam-gym')

from ballbeam_gym.envs.setpoint import BallBeamSetpointEnv


kwargs = {'timestep': 0.05, 
          'setpoint': 2,
          'beam_length': 5.0,
          'max_angle': 0.2,
          'init_velocity': 0.0,
          'action_mode': 'continuous'}

env = BallBeamSetpointEnv(**kwargs)
# Optional: PPO2 requires a vectorized environment to run
# the env is now wrapped automatically when passing it to the constructor
# env = DummyVecEnv([lambda: env])

model = PPO("MlpPolicy", env, verbose=0)
model.learn(total_timesteps=20000)

obs = env.reset()

ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []
episodic_reward = 0
obs_list = []
for ep in range(1000):
    obs = obs.astype(np.float)
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    #env.render()
    obs_list.append(obs)

    episodic_reward += rewards

   
    print("Episode * {} * Avg Reward is ==> {}, action = {}".format(ep, episodic_reward, action))
    avg_reward_list.append(episodic_reward)
# Out:
# C:\Users\NOTEBO~1\AppData\Local\Temp/ipykernel_57452/2383638188.py:38: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   obs = obs.astype(np.float)
# Episode * 0 * Avg Reward is ==> 0.8117566785919679, action = [0.2]
# Episode * 1 * Avg Reward is ==> 1.6270324228455142, action = [0.2]
# Episode * 2 * Avg Reward is ==> 2.4476010367855356, action = [0.2]
# Episode * 3 * Avg Reward is ==> 3.271707744645945, action = [-0.2]
# Episode * 4 * Avg Reward is ==> 4.101135864581044, action = [0.2]
# Episode * 5 * Avg Reward is ==> 4.934121106695342, action = [-0.2]
# Episode * 6 * Avg Reward is ==> 5.768887764138059, action = [-0.2]
# Episode * 7 * Avg Reward is ==> 6.603654421580776, action = [-0.2]
# Episode * 8 * Avg Reward is ==> 7.436639663695074, action = [-0.2]
# Episode * 9 * Avg Reward is ==> 8.266067783630172, action = [-0.2]
# Episode * 10 * Avg Reward is ==> 9.093720196714493, action = [0.2]
# Episode * 11 * Avg Reward is ==> 9.921372609798814, action = [0.2]
# Episode * 12 * Avg Reward is ==> 10.747251218858239, action = [-0.2]
# Episode * 13 * Avg Reward is ==> 11.573129827917663, action = [0.2]
# Episode * 14 * Avg Reward is ==> 12.397236535778072, action = [-0.2]
# Episode * 15 * Avg Reward is ==> 13.217805149718094, action = [-0.2]
# Episode * 16 * Avg Reward is ==> 14.03308089397164, action = [-0.2]
# Episode * 17 * Avg Reward is ==> 14.844837572563607, action = [0.2]
# Episode * 18 * Avg Reward is ==> 15.654837572563608, action = [0.2]
# Episode * 19 * Avg Reward is ==> 16.464837572563606, action = [0.2]
# Episode * 20 * Avg Reward is ==> 17.276594251155576, action = [0.2]
# Episode * 21 * Avg Reward is ==> 18.091869995409123, action = [0.2]
# Episode * 22 * Avg Reward is ==> 18.912438609349145, action = [0.2]
# Episode * 23 * Avg Reward is ==> 19.736545317209554, action = [-0.2]
# Episode * 24 * Avg Reward is ==> 20.56242392626898, action = [-0.2]
# Episode * 25 * Avg Reward is ==> 21.388302535328407, action = [-0.2]
# Episode * 26 * Avg Reward is ==> 22.212409243188816, action = [-0.2]
# Episode * 27 * Avg Reward is ==> 23.032977857128838, action = [-0.2]
# Episode * 28 * Avg Reward is ==> 23.851780278347487, action = [0.2]
# Episode * 29 * Avg Reward is ==> 24.670582699566136, action = [0.2]
# Episode * 30 * Avg Reward is ==> 25.49115131350616, action = [0.2]
# Episode * 31 * Avg Reward is ==> 26.315258021366567, action = [0.2]
# Episode * 32 * Avg Reward is ==> 27.142384970962024, action = [-0.05886466]
# Episode * 33 * Avg Reward is ==> 27.970761203833423, action = [-0.2]
# Episode * 34 * Avg Reward is ==> 28.798611743458803, action = [-0.2]
# Episode * 35 * Avg Reward is ==> 29.627712112485664, action = [0.2]
# Episode * 36 * Avg Reward is ==> 30.45984185162437, action = [0.2]
# Episode * 37 * Avg Reward is ==> 31.29322464499867, action = [-0.2]
# Episode * 38 * Avg Reward is ==> 32.12608015866945, action = [-0.2]
# Episode * 39 * Avg Reward is ==> 32.95743922320702, action = [-0.108448]
# Episode * 40 * Avg Reward is ==> 33.789081260614594, action = [0.2]
# Episode * 41 * Avg Reward is ==> 34.62199622524838, action = [0.11072019]
# Episode * 42 * Avg Reward is ==> 35.45796779175293, action = [0.2]
# Episode * 43 * Avg Reward is ==> 36.29878942620971, action = [0.2]
# Episode * 44 * Avg Reward is ==> 37.14268212282416, action = [-0.2]
# Episode * 45 * Avg Reward is ==> 37.987857084364784, action = [-0.2]
# Episode * 46 * Avg Reward is ==> 38.83252143064075, action = [-0.2]
# Episode * 47 * Avg Reward is ==> 39.678468627733565, action = [0.2]
# Episode * 48 * Avg Reward is ==> 40.52749622468399, action = [0.2]
# Episode * 49 * Avg Reward is ==> 41.3778099803148, action = [-0.2]
# Episode * 50 * Avg Reward is ==> 42.22964275537891, action = [0.02559134]
# Episode * 51 * Avg Reward is ==> 43.08479895702506, action = [0.2]
# Episode * 52 * Avg Reward is ==> 43.942736447659506, action = [-0.06034551]
# Episode * 53 * Avg Reward is ==> 44.80165082875386, action = [-0.2]
# Episode * 54 * Avg Reward is ==> 45.66335259868608, action = [0.2]
# Episode * 55 * Avg Reward is ==> 46.527208855498436, action = [-0.06988646]
# Episode * 56 * Avg Reward is ==> 47.395038659477166, action = [0.2]
# Episode * 57 * Avg Reward is ==> 48.265030592859084, action = [-0.2]
# Episode * 58 * Avg Reward is ==> 49.139010143653074, action = [0.2]
# Episode * 59 * Avg Reward is ==> 50.015159466373326, action = [-0.2]
# Episode * 60 * Avg Reward is ==> 50.89531047675135, action = [0.2]
# Episode * 61 * Avg Reward is ==> 51.78130758634145, action = [0.2]
# Episode * 62 * Avg Reward is ==> 52.671328784383554, action = [-0.2]
# Episode * 63 * Avg Reward is ==> 53.5635395642948, action = [-0.2]
# Episode * 64 * Avg Reward is ==> 54.45609863214718, action = [-0.2]
# Episode * 65 * Avg Reward is ==> 55.347163615145206, action = [-0.2]
# Episode * 66 * Avg Reward is ==> 56.237435648841505, action = [0.07562762]
# Episode * 67 * Avg Reward is ==> 57.125076187362296, action = [-0.2]
# Episode * 68 * Avg Reward is ==> 58.00825485194137, action = [-0.2]
# Episode * 69 * Avg Reward is ==> 58.88515513939774, action = [-0.2]
# Episode * 70 * Avg Reward is ==> 59.75398013061327, action = [-0.2]
# Episode * 71 * Avg Reward is ==> 60.61295819901036, action = [-0.2]
# Episode * 72 * Avg Reward is ==> 61.46394411108596, action = [0.2]
# Episode * 73 * Avg Reward is ==> 62.30518500478201, action = [-0.2]
# Episode * 74 * Avg Reward is ==> 63.13851688207593, action = [0.2]
# Episode * 75 * Avg Reward is ==> 63.965750452404635, action = [0.2]
# Episode * 76 * Avg Reward is ==> 64.78514128455689, action = [-0.2]
# Episode * 77 * Avg Reward is ==> 65.5984851291018, action = [0.2]
# Episode * 78 * Avg Reward is ==> 66.40755815254565, action = [0.2]
# Episode * 79 * Avg Reward is ==> 67.21210408467947, action = [-0.03037497]
# Episode * 80 * Avg Reward is ==> 68.01388146802556, action = [0.2]
# Episode * 81 * Avg Reward is ==> 68.81463980535163, action = [0.2]
# Episode * 82 * Avg Reward is ==> 69.61612526814847, action = [0.2]
# Episode * 83 * Avg Reward is ==> 70.4165918705143, action = [-0.2]
# Episode * 84 * Avg Reward is ==> 71.21539648752305, action = [-0.07340597]
# Episode * 85 * Avg Reward is ==> 72.01428353648554, action = [0.2]
# Episode * 86 * Avg Reward is ==> 72.81499770459206, action = [0.2]
# Episode * 87 * Avg Reward is ==> 73.61928965739006, action = [0.2]
# Episode * 88 * Avg Reward is ==> 74.42541489611494, action = [-0.2]
# Episode * 89 * Avg Reward is ==> 75.23162294364501, action = [-0.2]
# Episode * 90 * Avg Reward is ==> 76.03730236132492, action = [-0.06941567]
# Episode * 91 * Avg Reward is ==> 76.84420473792375, action = [0.2]
# Episode * 92 * Avg Reward is ==> 77.65057825704864, action = [-0.2]
# Episode * 93 * Avg Reward is ==> 78.45467282538542, action = [-0.2]
# Episode * 94 * Avg Reward is ==> 79.2582394573436, action = [0.2]
# Episode * 95 * Avg Reward is ==> 80.06302744425402, action = [0.2]
# Episode * 96 * Avg Reward is ==> 80.87079006284644, action = [0.2]
# Episode * 97 * Avg Reward is ==> 81.68190974837033, action = [0.04264198]
# Episode * 98 * Avg Reward is ==> 82.49463383393419, action = [-0.2]
# Episode * 99 * Avg Reward is ==> 83.30720444236277, action = [-0.2]
# Episode * 100 * Avg Reward is ==> 84.12138088444911, action = [0.2]
# Episode * 101 * Avg Reward is ==> 84.93540371232133, action = [-0.2]
# Episode * 102 * Avg Reward is ==> 85.74751397630148, action = [-0.2]
# Episode * 103 * Avg Reward is ==> 86.55595893338312, action = [-0.2]
# Episode * 104 * Avg Reward is ==> 87.35899775570904, action = [-0.2]
# Episode * 105 * Avg Reward is ==> 88.15490723904882, action = [-0.2]
# Episode * 106 * Avg Reward is ==> 88.94545273480242, action = [0.2]
# Episode * 107 * Avg Reward is ==> 89.72892469064983, action = [-0.2]
# Episode * 108 * Avg Reward is ==> 90.50363688637559, action = [-0.2]
# Episode * 109 * Avg Reward is ==> 91.27134689601145, action = [0.2]
# Episode * 110 * Avg Reward is ==> 92.03038595690411, action = [-0.2]
# Episode * 111 * Avg Reward is ==> 92.78249418552316, action = [0.2]
# Episode * 112 * Avg Reward is ==> 93.52938836623372, action = [0.2]
# Episode * 113 * Avg Reward is ==> 94.27276765977406, action = [0.2]
# Episode * 114 * Avg Reward is ==> 95.01431931173327, action = [0.2]
# Episode * 115 * Avg Reward is ==> 95.75473149615442, action = [0.08128959]
# Episode * 116 * Avg Reward is ==> 96.49232871596472, action = [-0.2]
# Episode * 117 * Avg Reward is ==> 97.22544505607262, action = [-0.2]
# Episode * 118 * Avg Reward is ==> 97.95576034813787, action = [0.2]
# Episode * 119 * Avg Reward is ==> 98.68494484183898, action = [0.2]
# Episode * 120 * Avg Reward is ==> 99.4145644053842, action = [0.18778843]
# Episode * 121 * Avg Reward is ==> 100.14628695352422, action = [0.2]
# Episode * 122 * Avg Reward is ==> 100.8817633264683, action = [0.19705978]
# Episode * 123 * Avg Reward is ==> 101.62115470196859, action = [0.01795346]
# Episode * 124 * Avg Reward is ==> 102.36615432884408, action = [0.2]
# Episode * 125 * Avg Reward is ==> 103.11654573231206, action = [-0.02794199]
# Episode * 126 * Avg Reward is ==> 103.87065333225696, action = [-0.2]
# Episode * 127 * Avg Reward is ==> 104.62719380597059, action = [-0.15185055]
# Episode * 128 * Avg Reward is ==> 105.3844724926928, action = [-0.2]
# Episode * 129 * Avg Reward is ==> 106.1441891589237, action = [0.2]
# Episode * 130 * Avg Reward is ==> 106.90805176257686, action = [0.2]
# Episode * 131 * Avg Reward is ==> 107.6777821614569, action = [0.2]
# Episode * 132 * Avg Reward is ==> 108.45168569480367, action = [-0.2]
# Episode * 133 * Avg Reward is ==> 109.23149538984171, action = [0.2]
# Episode * 134 * Avg Reward is ==> 110.01745665812847, action = [0.0256166]
# Episode * 135 * Avg Reward is ==> 110.8113308790223, action = [0.2]
# Episode * 136 * Avg Reward is ==> 111.61490548470361, action = [0.2]
# Episode * 137 * Avg Reward is ==> 112.42895500934769, action = [0.08088124]
# Episode * 138 * Avg Reward is ==> 113.25177676394246, action = [-0.2]
# Episode * 139 * Avg Reward is ==> 114.08163968518072, action = [-0.2]
# Episode * 140 * Avg Reward is ==> 114.91791291227507, action = [-0.07364753]
# Episode * 141 * Avg Reward is ==> 115.75883123486257, action = [-0.2]
# Episode * 142 * Avg Reward is ==> 116.60261459948379, action = [-0.2]
# Episode * 143 * Avg Reward is ==> 117.45106384176127, action = [0.2]
# Episode * 144 * Avg Reward is ==> 118.30599464041403, action = [0.2]
# Episode * 145 * Avg Reward is ==> 119.16759834869637, action = [0.01829016]
# Episode * 146 * Avg Reward is ==> 120.03408404200384, action = [-0.2]
# Episode * 147 * Avg Reward is ==> 120.90728750039435, action = [0.2]
# Episode * 148 * Avg Reward is ==> 121.78540565069841, action = [-0.2]
# Episode * 149 * Avg Reward is ==> 122.66662005113788, action = [-0.2]
# Episode * 150 * Avg Reward is ==> 123.5491025998036, action = [-0.2]
# Episode * 151 * Avg Reward is ==> 124.43468907675347, action = [0.2]
# Episode * 152 * Avg Reward is ==> 125.32433644207582, action = [0.10294487]
# Episode * 153 * Avg Reward is ==> 126.21621070834749, action = [-0.2]
# Episode * 154 * Avg Reward is ==> 127.10847098374104, action = [-0.2]
# Episode * 155 * Avg Reward is ==> 127.99927518050234, action = [-0.2]
# Episode * 156 * Avg Reward is ==> 128.89046515477446, action = [0.2]
# Episode * 157 * Avg Reward is ==> 129.78368441533627, action = [0.17810895]
# Episode * 158 * Avg Reward is ==> 130.67709041179324, action = [-0.2]
# Episode * 159 * Avg Reward is ==> 131.5688400156124, action = [-0.2]
# Episode * 160 * Avg Reward is ==> 132.46077620164874, action = [0.2]
# Episode * 161 * Avg Reward is ==> 133.3510573587695, action = [-0.2]
# Episode * 162 * Avg Reward is ==> 134.2378470061812, action = [-0.2]
# Episode * 163 * Avg Reward is ==> 135.1229864086257, action = [0.2]
# Episode * 164 * Avg Reward is ==> 136.0081909178311, action = [0.18667842]
# Episode * 165 * Avg Reward is ==> 136.89394800949205, action = [0.05278023]
# Episode * 166 * Avg Reward is ==> 137.77842223818533, action = [-0.2]
# Episode * 167 * Avg Reward is ==> 138.6634488213866, action = [0.2]
# Episode * 168 * Avg Reward is ==> 139.55086469492815, action = [0.2]
# Episode * 169 * Avg Reward is ==> 140.43939249305032, action = [-0.1387483]
# Episode * 170 * Avg Reward is ==> 141.32719384659944, action = [-0.2]
# Episode * 171 * Avg Reward is ==> 142.21243264201908, action = [-0.2]
# Episode * 172 * Avg Reward is ==> 143.09328072982768, action = [-0.2]
# Episode * 173 * Avg Reward is ==> 143.97157632148426, action = [0.2]
# Episode * 174 * Avg Reward is ==> 144.8483302144401, action = [0.10978548]
# Episode * 175 * Avg Reward is ==> 145.72536975082545, action = [0.2]
# Episode * 176 * Avg Reward is ==> 146.60086869178465, action = [-0.2]
# Episode * 177 * Avg Reward is ==> 147.47300561434196, action = [-0.2]
# Episode * 178 * Avg Reward is ==> 148.33996961987907, action = [-0.2]
# Episode * 179 * Avg Reward is ==> 149.20358805052626, action = [0.2]
# Episode * 180 * Avg Reward is ==> 150.06567772405626, action = [0.2]
# Episode * 181 * Avg Reward is ==> 150.92443124996998, action = [-0.2]
# Episode * 182 * Avg Reward is ==> 151.7816603326277, action = [0.2]
# Episode * 183 * Avg Reward is ==> 152.6391718605098, action = [0.2]
# Episode * 184 * Avg Reward is ==> 153.49877361469447, action = [0.2]
# Episode * 185 * Avg Reward is ==> 154.36227997733533, action = [0.2]
# Episode * 186 * Avg Reward is ==> 155.23151764013903, action = [0.2]
# Episode * 187 * Avg Reward is ==> 156.10468171049754, action = [-0.2]
# Episode * 188 * Avg Reward is ==> 156.9799549862498, action = [-0.2]
# Episode * 189 * Avg Reward is ==> 157.85551366415925, action = [-0.2]
# Episode * 190 * Avg Reward is ==> 158.73221037553756, action = [0.09288798]
# Episode * 191 * Avg Reward is ==> 159.61004728247644, action = [0.00015467]
# Episode * 192 * Avg Reward is ==> 160.48754948152487, action = [-0.16105364]
# Episode * 193 * Avg Reward is ==> 161.36654506050837, action = [0.2]
# Episode * 194 * Avg Reward is ==> 162.24520571075985, action = [-0.2]
# Episode * 195 * Avg Reward is ==> 163.1253607259593, action = [0.2]
# Episode * 196 * Avg Reward is ==> 164.00884406280733, action = [0.2]
# Episode * 197 * Avg Reward is ==> 164.8975000495027, action = [0.2]
# Episode * 198 * Avg Reward is ==> 165.79318909421997, action = [0.2]
# Episode * 199 * Avg Reward is ==> 166.6977933935872, action = [0.2]
# Episode * 200 * Avg Reward is ==> 167.61322264116353, action = [0.2]
# Episode * 201 * Avg Reward is ==> 168.5376646082577, action = [-0.2]
# Episode * 202 * Avg Reward is ==> 169.46927956924728, action = [-0.2]
# Episode * 203 * Avg Reward is ==> 170.4062060100564, action = [-0.2]
# Episode * 204 * Avg Reward is ==> 171.34656633663334, action = [-0.2]
# Episode * 205 * Avg Reward is ==> 172.28847258342824, action = [-0.2]
# Episode * 206 * Avg Reward is ==> 173.23028691145728, action = [-0.17278887]
# Episode * 207 * Avg Reward is ==> 174.173903387171, action = [0.2]
# Episode * 208 * Avg Reward is ==> 175.1212215083464, action = [0.2]
# Episode * 209 * Avg Reward is ==> 176.07034703273607, action = [-0.2]
# Episode * 210 * Avg Reward is ==> 177.02318498182723, action = [0.2]
# Episode * 211 * Avg Reward is ==> 177.9780208998736, action = [-0.18033111]
# Episode * 212 * Avg Reward is ==> 178.93347201478443, action = [-0.14473698]
# Episode * 213 * Avg Reward is ==> 179.88763200231938, action = [-0.2]
# Episode * 214 * Avg Reward is ==> 180.83859840473292, action = [-0.2]
# Episode * 215 * Avg Reward is ==> 181.78644575328045, action = [0.00723645]
# Episode * 216 * Avg Reward is ==> 182.72928398824504, action = [-0.2]
# Episode * 217 * Avg Reward is ==> 183.66523812543267, action = [-0.2]
# Episode * 218 * Avg Reward is ==> 184.59621471618473, action = [0.2]
# Episode * 219 * Avg Reward is ==> 185.52410523631974, action = [0.2]
# Episode * 220 * Avg Reward is ==> 186.44703972681793, action = [-0.2]
# Episode * 221 * Avg Reward is ==> 187.36316330418248, action = [-0.2]
# Episode * 222 * Avg Reward is ==> 188.27436241905755, action = [0.2]
# Episode * 223 * Avg Reward is ==> 189.1812751176536, action = [0.06687379]
# Episode * 224 * Avg Reward is ==> 190.08576586474499, action = [0.2]
# Episode * 225 * Avg Reward is ==> 190.98792051829366, action = [0.0088588]
# Episode * 226 * Avg Reward is ==> 191.8895935659049, action = [0.2]
# Episode * 227 * Avg Reward is ==> 192.78893416390406, action = [-0.2]
# Episode * 228 * Avg Reward is ==> 193.68409866102985, action = [-0.2]
# Episode * 229 * Avg Reward is ==> 194.5769391474164, action = [0.2]
# Episode * 230 * Avg Reward is ==> 195.46930052078446, action = [0.2]
# Episode * 231 * Avg Reward is ==> 196.35934152734387, action = [-0.2]
# Episode * 232 * Avg Reward is ==> 197.24522810571787, action = [-0.2]
# Episode * 233 * Avg Reward is ==> 198.12880275615606, action = [0.2]
# Episode * 234 * Avg Reward is ==> 199.01190078649475, action = [0.2]
# Episode * 235 * Avg Reward is ==> 199.89635602063444, action = [0.2]
# Episode * 236 * Avg Reward is ==> 200.78033439719837, action = [-0.2]
# Episode * 237 * Avg Reward is ==> 201.66200333874548, action = [-0.2]
# Episode * 238 * Avg Reward is ==> 202.54319617453106, action = [0.2]
# Episode * 239 * Avg Reward is ==> 203.42208321923042, action = [-0.2]
# Episode * 240 * Avg Reward is ==> 204.29684197993222, action = [-0.2]
# Episode * 241 * Avg Reward is ==> 205.1677554250964, action = [0.02982548]
# Episode * 242 * Avg Reward is ==> 206.03664950934316, action = [0.2]
# Episode * 243 * Avg Reward is ==> 206.90171120409414, action = [-0.2]
# Episode * 244 * Avg Reward is ==> 207.76476033744493, action = [0.2]
# Episode * 245 * Avg Reward is ==> 208.62399000734177, action = [-0.2]
# Episode * 246 * Avg Reward is ==> 209.47760535575682, action = [-0.2]
# Episode * 247 * Avg Reward is ==> 210.32382927716557, action = [-0.2]
# Episode * 248 * Avg Reward is ==> 211.16090812702467, action = [-0.2]
# Episode * 249 * Avg Reward is ==> 211.98893918172843, action = [0.00532648]
# Episode * 250 * Avg Reward is ==> 212.80973804575228, action = [0.2]
# Episode * 251 * Avg Reward is ==> 213.62254787921307, action = [-0.08917195]
# Episode * 252 * Avg Reward is ==> 214.42915885099666, action = [0.2]
# Episode * 253 * Avg Reward is ==> 215.2278503098382, action = [-0.2]
# Episode * 254 * Avg Reward is ==> 216.0203970829385, action = [0.2]
# Episode * 255 * Avg Reward is ==> 216.8085538392095, action = [0.2]
# Episode * 256 * Avg Reward is ==> 217.59406079775206, action = [0.2]
# Episode * 257 * Avg Reward is ==> 218.3786494363334, action = [0.2]
# Episode * 258 * Avg Reward is ==> 219.1640481998649, action = [0.2]
# Episode * 259 * Avg Reward is ==> 219.94904900791346, action = [-0.13930473]
# Episode * 260 * Avg Reward is ==> 220.73434554825388, action = [0.07981002]
# Episode * 261 * Avg Reward is ==> 221.52166790023907, action = [0.2]
# Episode * 262 * Avg Reward is ==> 222.31275282832618, action = [0.2]
# Episode * 263 * Avg Reward is ==> 223.1093494905544, action = [0.2]
# Episode * 264 * Avg Reward is ==> 223.91322514702244, action = [0.2]
# Episode * 265 * Avg Reward is ==> 224.72483405293931, action = [0.04763216]
# Episode * 266 * Avg Reward is ==> 225.54244831573067, action = [-0.2]
# Episode * 267 * Avg Reward is ==> 226.3650610322388, action = [-0.11576712]
# Episode * 268 * Avg Reward is ==> 227.19446311382933, action = [0.2]
# Episode * 269 * Avg Reward is ==> 228.02889949767734, action = [-0.2]
# Episode * 270 * Avg Reward is ==> 228.87017376544568, action = [0.2]
# Episode * 271 * Avg Reward is ==> 229.7165181840122, action = [-0.2]
# Episode * 272 * Avg Reward is ==> 230.5661488690477, action = [-0.2]
# Episode * 273 * Avg Reward is ==> 231.4172714934937, action = [-0.2]
# Episode * 274 * Avg Reward is ==> 232.26808699603993, action = [-0.2]
# Episode * 275 * Avg Reward is ==> 233.12039547743947, action = [0.2]
# Episode * 276 * Avg Reward is ==> 233.9723966230402, action = [-0.2]
# Episode * 277 * Avg Reward is ==> 234.82589178693706, action = [0.2]
# Episode * 278 * Avg Reward is ==> 235.6826870574768, action = [0.2]
# Episode * 279 * Avg Reward is ==> 236.54098054192335, action = [-0.2]
# Episode * 280 * Avg Reward is ==> 237.39896561328888, action = [-0.2]
# Episode * 281 * Avg Reward is ==> 238.25483661881157, action = [-0.2]
# Episode * 282 * Avg Reward is ==> 239.11039964683812, action = [0.2]
# Episode * 283 * Avg Reward is ==> 239.96738163913477, action = [0.19123326]
# Episode * 284 * Avg Reward is ==> 240.82759214629306, action = [0.2]
# Episode * 285 * Avg Reward is ==> 241.68922546486476, action = [-0.2]
# Episode * 286 * Avg Reward is ==> 242.55047140424446, action = [-0.2]
# Episode * 287 * Avg Reward is ==> 243.40952099514732, action = [-0.2]
# Episode * 288 * Avg Reward is ==> 244.2645721980866, action = [-0.2]
# Episode * 289 * Avg Reward is ==> 245.1165698050603, action = [0.10342333]
# Episode * 290 * Avg Reward is ==> 245.96731767411973, action = [0.2]
# Episode * 291 * Avg Reward is ==> 246.81861569994382, action = [0.2]
# Episode * 292 * Avg Reward is ==> 247.67226552231665, action = [0.2]
# Episode * 293 * Avg Reward is ==> 248.5264664388131, action = [-0.2]
# Episode * 294 * Avg Reward is ==> 249.37941600190285, action = [-0.2]
# Episode * 295 * Avg Reward is ==> 250.2293157274281, action = [-0.2]
# Episode * 296 * Avg Reward is ==> 251.0779672551729, action = [0.2]
# Episode * 297 * Avg Reward is ==> 251.92591900752575, action = [0.06059752]
# Episode * 298 * Avg Reward is ==> 252.77137657782495, action = [-0.2]
# Episode * 299 * Avg Reward is ==> 253.61313450044554, action = [-0.13457201]
# Episode * 300 * Avg Reward is ==> 254.44941595322038, action = [-0.2]
# Episode * 301 * Avg Reward is ==> 255.2784616092658, action = [-0.2]
# Episode * 302 * Avg Reward is ==> 256.10207237346987, action = [0.2]
# Episode * 303 * Avg Reward is ==> 256.9220316554371, action = [0.2]
# Episode * 304 * Avg Reward is ==> 257.73658596004503, action = [-0.2]
# Episode * 305 * Avg Reward is ==> 258.5475089362017, action = [0.2]
# Episode * 306 * Avg Reward is ==> 259.3565624460093, action = [0.2]
# Episode * 307 * Avg Reward is ==> 260.16550227324177, action = [0.2]
# Episode * 308 * Avg Reward is ==> 260.9760838318224, action = [0.2]
# Episode * 309 * Avg Reward is ==> 261.7900678743016, action = [0.2]
# Episode * 310 * Avg Reward is ==> 262.60569875616403, action = [-0.2]
# Episode * 311 * Avg Reward is ==> 263.4247426918706, action = [0.2]
# Episode * 312 * Avg Reward is ==> 264.2455322877666, action = [-0.18926278]
# Episode * 313 * Avg Reward is ==> 265.06630109107476, action = [-0.2]
# Episode * 314 * Avg Reward is ==> 265.88688902711664, action = [-0.01799614]
# Episode * 315 * Avg Reward is ==> 266.705530097037, action = [-0.2]
# Episode * 316 * Avg Reward is ==> 267.5204645946822, action = [-0.2]
# Episode * 317 * Avg Reward is ==> 268.33345894825084, action = [0.2]
# Episode * 318 * Avg Reward is ==> 269.14627329324003, action = [0.2]
# Episode * 319 * Avg Reward is ==> 269.9571500210632, action = [-0.2]
# Episode * 320 * Avg Reward is ==> 270.7678469749092, action = [0.2]
# Episode * 321 * Avg Reward is ==> 271.58012141374286, action = [0.2]
# Episode * 322 * Avg Reward is ==> 272.39573572078285, action = [0.2]
# Episode * 323 * Avg Reward is ==> 273.21293228744264, action = [-0.2]
# Episode * 324 * Avg Reward is ==> 274.03347881593606, action = [0.2]
# Episode * 325 * Avg Reward is ==> 274.85809710535824, action = [0.08028314]
# Episode * 326 * Avg Reward is ==> 275.68502230628843, action = [-0.2]
# Episode * 327 * Avg Reward is ==> 276.516035044261, action = [0.2]
# Episode * 328 * Avg Reward is ==> 277.3529290818851, action = [0.2]
# Episode * 329 * Avg Reward is ==> 278.1939351907152, action = [-0.2]
# Episode * 330 * Avg Reward is ==> 279.040141333341, action = [0.11965361]
# Episode * 331 * Avg Reward is ==> 279.8918595019672, action = [0.03266814]
# Episode * 332 * Avg Reward is ==> 280.7509147500196, action = [0.2]
# Episode * 333 * Avg Reward is ==> 281.6155236470515, action = [-0.2]
# Episode * 334 * Avg Reward is ==> 282.48388525715944, action = [-0.2]
# Episode * 335 * Avg Reward is ==> 283.35418684746094, action = [-0.2]
# Episode * 336 * Avg Reward is ==> 284.2282534713819, action = [0.2]
# Episode * 337 * Avg Reward is ==> 285.10426643421295, action = [-0.2]
# Episode * 338 * Avg Reward is ==> 285.9827595520234, action = [0.05780718]
# Episode * 339 * Avg Reward is ==> 286.86190624670115, action = [-0.2]
# Episode * 340 * Avg Reward is ==> 287.739877900029, action = [-0.2]
# Episode * 341 * Avg Reward is ==> 288.61850293625315, action = [0.2]
# Episode * 342 * Avg Reward is ==> 289.49961181972475, action = [0.2]
# Episode * 343 * Avg Reward is ==> 290.38504276337767, action = [0.2]
# Episode * 344 * Avg Reward is ==> 291.2729671489947, action = [-0.2]
# Episode * 345 * Avg Reward is ==> 292.16154860977605, action = [-0.2]
# Episode * 346 * Avg Reward is ==> 293.04894873881693, action = [-0.2]
# Episode * 347 * Avg Reward is ==> 293.9333327975852, action = [-0.2]
# Episode * 348 * Avg Reward is ==> 294.8165383189796, action = [0.2]
# Episode * 349 * Avg Reward is ==> 295.6984983457556, action = [-0.00734602]
# Episode * 350 * Avg Reward is ==> 296.5773839443253, action = [-0.2]
# Episode * 351 * Avg Reward is ==> 297.45502709905935, action = [0.2]
# Episode * 352 * Avg Reward is ==> 298.3310782832907, action = [-0.03813154]
# Episode * 353 * Avg Reward is ==> 299.2049776977637, action = [-0.06117004]
# Episode * 354 * Avg Reward is ==> 300.07855036172583, action = [0.2]
# Episode * 355 * Avg Reward is ==> 300.95362027152765, action = [0.2]
# Episode * 356 * Avg Reward is ==> 301.8301931181494, action = [0.00047958]
# Episode * 357 * Avg Reward is ==> 302.7100991621206, action = [0.2]
# Episode * 358 * Avg Reward is ==> 303.5951790718093, action = [0.2]
# Episode * 359 * Avg Reward is ==> 304.4857601485368, action = [0.03369316]
# Episode * 360 * Avg Reward is ==> 305.3800137028878, action = [-0.2]
# Episode * 361 * Avg Reward is ==> 306.27978822943845, action = [0.19905949]
# Episode * 362 * Avg Reward is ==> 307.183245516945, action = [-0.2]
# Episode * 363 * Avg Reward is ==> 308.09073647588326, action = [0.0367215]
# Episode * 364 * Avg Reward is ==> 309.0004085225334, action = [-0.2]
# Episode * 365 * Avg Reward is ==> 309.9104023774593, action = [-0.2]
# Episode * 366 * Avg Reward is ==> 310.8225803239854, action = [0.2]
# Episode * 367 * Avg Reward is ==> 311.73508052169046, action = [-0.2]
# Episode * 368 * Avg Reward is ==> 312.6470483031933, action = [-0.0912544]
# Episode * 369 * Avg Reward is ==> 313.5603471947231, action = [0.2]
# Episode * 370 * Avg Reward is ==> 314.4768447997991, action = [0.2]
# Episode * 371 * Avg Reward is ==> 315.3984185077082, action = [0.2]
# Episode * 372 * Avg Reward is ==> 316.32696120198256, action = [0.2]
# Episode * 373 * Avg Reward is ==> 317.2643869688772, action = [0.2]
# Episode * 374 * Avg Reward is ==> 318.2088412912115, action = [-0.2]
# Episode * 375 * Avg Reward is ==> 319.162254293215, action = [0.2]
# Episode * 376 * Avg Reward is ==> 320.1249449050964, action = [0.02871978]
# Episode * 377 * Avg Reward is ==> 321.0950356841607, action = [-0.2]
# Episode * 378 * Avg Reward is ==> 322.0744846709808, action = [0.2]
# Episode * 379 * Avg Reward is ==> 323.0652776424384, action = [0.2]
# Episode * 380 * Avg Reward is ==> 324.0650274057876, action = [-0.2]
# Episode * 381 * Avg Reward is ==> 325.0572645145211, action = [-0.2]
# Episode * 382 * Avg Reward is ==> 326.0439541323211, action = [-0.2]
# Episode * 383 * Avg Reward is ==> 327.0270451035164, action = [-0.2]
# Episode * 384 * Avg Reward is ==> 328.00847566155977, action = [-0.2]
# Episode * 385 * Avg Reward is ==> 328.99017913750583, action = [-0.2]
# Episode * 386 * Avg Reward is ==> 329.9740896684886, action = [-0.2]
# Episode * 387 * Avg Reward is ==> 330.95827346195017, action = [0.2]
# Episode * 388 * Avg Reward is ==> 331.9407959192531, action = [0.2]
# Episode * 389 * Avg Reward is ==> 332.9220528318284, action = [-0.04056126]
# Episode * 390 * Avg Reward is ==> 333.9039771603281, action = [-0.2]
# Episode * 391 * Avg Reward is ==> 334.88850383663356, action = [-0.2]
# Episode * 392 * Avg Reward is ==> 335.8775754723331, action = [-0.2]
# Episode * 393 * Avg Reward is ==> 336.8731480671997, action = [-0.2]
# Episode * 394 * Avg Reward is ==> 337.8691075959671, action = [-0.2]
# Episode * 395 * Avg Reward is ==> 338.85856490030733, action = [0.2]
# Episode * 396 * Avg Reward is ==> 339.84029637541784, action = [-0.128265]
# Episode * 397 * Avg Reward is ==> 340.8124079372962, action = [-0.2]
# Episode * 398 * Avg Reward is ==> 341.7730339824927, action = [-0.2]
# Episode * 399 * Avg Reward is ==> 342.72316246169197, action = [0.09625992]
# Episode * 400 * Avg Reward is ==> 343.6609609345314, action = [-0.2]
# Episode * 401 * Avg Reward is ==> 344.5883355639676, action = [0.1943815]
# Episode * 402 * Avg Reward is ==> 345.50721366253543, action = [0.2]
# Episode * 403 * Avg Reward is ==> 346.41577390095034, action = [-0.2]
# Episode * 404 * Avg Reward is ==> 347.31592443742636, action = [0.2]
# Episode * 405 * Avg Reward is ==> 348.2058630969997, action = [-0.2]
# Episode * 406 * Avg Reward is ==> 349.08747888356356, action = [0.2]
# Episode * 407 * Avg Reward is ==> 349.9626349237689, action = [0.2]
# Episode * 408 * Avg Reward is ==> 350.8295376683993, action = [-0.2]
# Episode * 409 * Avg Reward is ==> 351.69003489543667, action = [0.2]
# Episode * 410 * Avg Reward is ==> 352.545954214098, action = [0.2]
# Episode * 411 * Avg Reward is ==> 353.3991087733133, action = [0.2]
# Episode * 412 * Avg Reward is ==> 354.251302970203, action = [0.2]
# Episode * 413 * Avg Reward is ==> 355.10433815855595, action = [0.2]
# Episode * 414 * Avg Reward is ==> 355.9600183573065, action = [0.2]
# Episode * 415 * Avg Reward is ==> 356.8201559590127, action = [0.2]
# Episode * 416 * Avg Reward is ==> 357.6829495510307, action = [-0.2]
# Episode * 417 * Avg Reward is ==> 358.55021901115987, action = [0.2]
# Episode * 418 * Avg Reward is ==> 359.4237982993009, action = [0.2]
# Episode * 419 * Avg Reward is ==> 360.3018813087762, action = [-0.2]
# Episode * 420 * Avg Reward is ==> 361.1826478508071, action = [-0.2]
# Episode * 421 * Avg Reward is ==> 362.0679365793278, action = [0.2]
# Episode * 422 * Avg Reward is ==> 362.9596002303738, action = [0.2]
# Episode * 423 * Avg Reward is ==> 363.85581392113266, action = [-0.2]
# Episode * 424 * Avg Reward is ==> 364.75473868669087, action = [-0.2]
# Episode * 425 * Avg Reward is ==> 365.6545271885115, action = [-0.2]
# Episode * 426 * Avg Reward is ==> 366.5570321626299, action = [0.2]
# Episode * 427 * Avg Reward is ==> 367.4604025909194, action = [-0.2]
# Episode * 428 * Avg Reward is ==> 368.36278479010736, action = [-0.2]
# Episode * 429 * Avg Reward is ==> 369.26232812025313, action = [-0.2]
# Episode * 430 * Avg Reward is ==> 370.1571906932254, action = [-0.2]
# Episode * 431 * Avg Reward is ==> 371.0492262595035, action = [0.2]
# Episode * 432 * Avg Reward is ==> 371.9391007405461, action = [0.07148236]
# Episode * 433 * Avg Reward is ==> 372.82678885515327, action = [-0.00301593]
# Episode * 434 * Avg Reward is ==> 373.7141299785261, action = [0.2]
# Episode * 435 * Avg Reward is ==> 374.6029624080698, action = [0.2]
# Episode * 436 * Avg Reward is ==> 375.4914476227769, action = [-0.2]
# Episode * 437 * Avg Reward is ==> 376.3814251043478, action = [0.2]
# Episode * 438 * Avg Reward is ==> 377.2747389651648, action = [0.2]
# Episode * 439 * Avg Reward is ==> 378.16954914065974, action = [-0.2]
# Episode * 440 * Avg Reward is ==> 379.06585010460174, action = [-0.00072914]
# Episode * 441 * Avg Reward is ==> 379.96549247760885, action = [0.2]
# Episode * 442 * Avg Reward is ==> 380.8666296572844, action = [-0.2]
# Episode * 443 * Avg Reward is ==> 381.7674104315011, action = [-0.2]
# Episode * 444 * Avg Reward is ==> 382.66942925070737, action = [0.171883]
# Episode * 445 * Avg Reward is ==> 383.5738706272235, action = [0.12713543]
# Episode * 446 * Avg Reward is ==> 384.4825965073718, action = [0.2]
# Episode * 447 * Avg Reward is ==> 385.3974820049542, action = [0.2]
# Episode * 448 * Avg Reward is ==> 386.316676643871, action = [-0.2]
# Episode * 449 * Avg Reward is ==> 387.23831678054256, action = [-0.2]
# Episode * 450 * Avg Reward is ==> 388.160531312387, action = [-0.2]
# Episode * 451 * Avg Reward is ==> 389.0814473862977, action = [-0.2]
# Episode * 452 * Avg Reward is ==> 389.9991961071213, action = [-0.2]
# Episode * 453 * Avg Reward is ==> 390.9119182461349, action = [-0.2]
# Episode * 454 * Avg Reward is ==> 391.82148716661595, action = [0.2]
# Episode * 455 * Avg Reward is ==> 392.72976656541124, action = [0.2]
# Episode * 456 * Avg Reward is ==> 393.6386161814145, action = [0.2]
# Episode * 457 * Avg Reward is ==> 394.5498975040441, action = [0.2]
# Episode * 458 * Avg Reward is ==> 395.4643998528401, action = [0.08382772]
# Episode * 459 * Avg Reward is ==> 396.38026102325233, action = [-0.2]
# Episode * 460 * Avg Reward is ==> 397.2956146543573, action = [-0.2]
# Episode * 461 * Avg Reward is ==> 398.2085959373353, action = [-0.2]
# Episode * 462 * Avg Reward is ==> 399.1173473239484, action = [-0.2]
# Episode * 463 * Avg Reward is ==> 400.02373493909136, action = [0.2]
# Episode * 464 * Avg Reward is ==> 400.92590797773977, action = [-0.2]
# Episode * 465 * Avg Reward is ==> 401.82572582157474, action = [0.2]
# Episode * 466 * Avg Reward is ==> 402.7250405916957, action = [0.2]
# Episode * 467 * Avg Reward is ==> 403.62459398742493, action = [0.07972565]
# Episode * 468 * Avg Reward is ==> 404.5262374769586, action = [0.2]
# Episode * 469 * Avg Reward is ==> 405.4318289732424, action = [0.2]
# Episode * 470 * Avg Reward is ==> 406.3395175622368, action = [-0.2]
# Episode * 471 * Avg Reward is ==> 407.247445885153, action = [-0.2]
# Episode * 472 * Avg Reward is ==> 408.1537558469304, action = [-0.2]
# Episode * 473 * Avg Reward is ==> 409.0565943247141, action = [-0.2]
# Episode * 474 * Avg Reward is ==> 409.9578189860259, action = [0.2]
# Episode * 475 * Avg Reward is ==> 410.85558192564076, action = [-0.2]
# Episode * 476 * Avg Reward is ==> 411.7517355934506, action = [0.2]
# Episode * 477 * Avg Reward is ==> 412.64812746714136, action = [0.2]
# Episode * 478 * Avg Reward is ==> 413.5429112988901, action = [-0.2]
# Episode * 479 * Avg Reward is ==> 414.4379331544048, action = [0.2]
# Episode * 480 * Avg Reward is ==> 415.3346379656574, action = [0.15608796]
# Episode * 481 * Avg Reward is ==> 416.2344638241433, action = [0.15490219]
# Episode * 482 * Avg Reward is ==> 417.1392708353042, action = [0.2]
# Episode * 483 * Avg Reward is ==> 418.0472129499228, action = [-0.2]
# Episode * 484 * Avg Reward is ==> 418.9564344826224, action = [-0.2]
# Episode * 485 * Avg Reward is ==> 419.8663532081902, action = [-0.06228575]
# Episode * 486 * Avg Reward is ==> 420.7751087630939, action = [-0.2]
# Episode * 487 * Avg Reward is ==> 421.68084435313165, action = [-0.2]
# Episode * 488 * Avg Reward is ==> 422.58171246190994, action = [-0.2]
# Episode * 489 * Avg Reward is ==> 423.47588055932124, action = [-0.2]
# Episode * 490 * Avg Reward is ==> 424.36274485810617, action = [-0.06803857]
# Episode * 491 * Avg Reward is ==> 425.244165856004, action = [0.2]
# Episode * 492 * Avg Reward is ==> 426.12198711098563, action = [0.2]
# Episode * 493 * Avg Reward is ==> 426.99804094973126, action = [0.2]
# Episode * 494 * Avg Reward is ==> 427.87415417610805, action = [0.2]
# Episode * 495 * Avg Reward is ==> 428.7485017074359, action = [-0.2]
# Episode * 496 * Avg Reward is ==> 429.6229085685324, action = [0.2]
# Episode * 497 * Avg Reward is ==> 430.49574619558234, action = [-0.17838494]
# Episode * 498 * Avg Reward is ==> 431.366790544532, action = [-0.0246019]
# Episode * 499 * Avg Reward is ==> 432.23786322198737, action = [0.2]
# Episode * 500 * Avg Reward is ==> 433.10724941164705, action = [-0.18831441]
# Episode * 501 * Avg Reward is ==> 433.97676888625926, action = [0.2]
# Episode * 502 * Avg Reward is ==> 434.84824183684924, action = [0.2]
# Episode * 503 * Avg Reward is ==> 435.72349458119663, action = [0.2]
# Episode * 504 * Avg Reward is ==> 436.6043652723133, action = [0.2]
# Episode * 505 * Avg Reward is ==> 437.4927096069211, action = [0.2]
# Episode * 506 * Avg Reward is ==> 438.3867136806072, action = [-0.2]
# Episode * 507 * Avg Reward is ==> 439.28454604524916, action = [-0.2]
# Episode * 508 * Avg Reward is ==> 440.18436341749214, action = [-0.2]
# Episode * 509 * Avg Reward is ==> 441.08431638722686, action = [-0.2]
# Episode * 510 * Avg Reward is ==> 441.98625670609766, action = [0.2]
# Episode * 511 * Avg Reward is ==> 442.8920422525035, action = [0.2]
# Episode * 512 * Avg Reward is ==> 443.7998215740834, action = [-0.2]
# Episode * 513 * Avg Reward is ==> 444.70773709172215, action = [-0.2]
# Episode * 514 * Avg Reward is ==> 445.6139308080274, action = [-0.2]
# Episode * 515 * Avg Reward is ==> 446.51655001580764, action = [-0.2]
# Episode * 516 * Avg Reward is ==> 447.41375300654965, action = [-0.2]
# Episode * 517 * Avg Reward is ==> 448.30371477889634, action = [-0.2]
# Episode * 518 * Avg Reward is ==> 449.18463274712417, action = [-0.2]
# Episode * 519 * Avg Reward is ==> 450.05837564888475, action = [0.2]
# Episode * 520 * Avg Reward is ==> 450.9267898061961, action = [0.2]
# Episode * 521 * Avg Reward is ==> 451.79170483392016, action = [0.2]
# Episode * 522 * Avg Reward is ==> 452.65493934824053, action = [0.2]
# Episode * 523 * Avg Reward is ==> 453.5146851943817, action = [-0.2]
# Episode * 524 * Avg Reward is ==> 454.37275555890085, action = [0.2]
# Episode * 525 * Avg Reward is ==> 455.22734771664886, action = [-0.2]
# Episode * 526 * Avg Reward is ==> 456.0802694245566, action = [0.2]
# Episode * 527 * Avg Reward is ==> 456.9333231493542, action = [0.2]
# Episode * 528 * Avg Reward is ==> 457.7847079292927, action = [-0.2]
# Episode * 529 * Avg Reward is ==> 458.6362246071277, action = [0.2]
# Episode * 530 * Avg Reward is ==> 459.48713610543814, action = [-0.08144782]
# Episode * 531 * Avg Reward is ==> 460.3392424711289, action = [0.2]
# Episode * 532 * Avg Reward is ==> 461.1943475401599, action = [0.2]
# Episode * 533 * Avg Reward is ==> 462.05097198018257, action = [-0.16401793]
# Episode * 534 * Avg Reward is ==> 462.9073109383295, action = [-0.2]
# Episode * 535 * Avg Reward is ==> 463.7615604643956, action = [-0.2]
# Episode * 536 * Avg Reward is ==> 464.6119232193157, action = [-0.2]
# Episode * 537 * Avg Reward is ==> 465.4602038502264, action = [0.2]
# Episode * 538 * Avg Reward is ==> 466.3046113283149, action = [-0.2]
# Episode * 539 * Avg Reward is ==> 467.143366944386, action = [-0.2]
# Episode * 540 * Avg Reward is ==> 467.9782712390371, action = [0.2]
# Episode * 541 * Avg Reward is ==> 468.81111243324807, action = [0.2]
# Episode * 542 * Avg Reward is ==> 469.6401159243629, action = [-0.2]
# Episode * 543 * Avg Reward is ==> 470.4670636231088, action = [0.2]
# Episode * 544 * Avg Reward is ==> 471.2901872370824, action = [-0.2]
# Episode * 545 * Avg Reward is ==> 472.1077307934977, action = [-0.2]
# Episode * 546 * Avg Reward is ==> 472.9214720965428, action = [0.2]
# Episode * 547 * Avg Reward is ==> 473.7324801231541, action = [0.12021121]
# Episode * 548 * Avg Reward is ==> 474.54251428424845, action = [0.2]
# Episode * 549 * Avg Reward is ==> 475.35333082538625, action = [0.2]
# Episode * 550 * Avg Reward is ==> 476.16668853524897, action = [0.2]
# Episode * 551 * Avg Reward is ==> 476.9824806593501, action = [-0.01248504]
# Episode * 552 * Avg Reward is ==> 477.8024764111675, action = [0.2]
# Episode * 553 * Avg Reward is ==> 478.6284586055252, action = [0.2]
# Episode * 554 * Avg Reward is ==> 479.462229367071, action = [0.2]
# Episode * 555 * Avg Reward is ==> 480.30203655344303, action = [-0.2]
# Episode * 556 * Avg Reward is ==> 481.1461087124556, action = [-0.2]
# Episode * 557 * Avg Reward is ==> 481.99266079057696, action = [-0.2]
# Episode * 558 * Avg Reward is ==> 482.84349491245496, action = [0.2]
# Episode * 559 * Avg Reward is ==> 483.69681885981953, action = [-0.2]
# Episode * 560 * Avg Reward is ==> 484.5508325215323, action = [-0.2]
# Episode * 561 * Avg Reward is ==> 485.4073406531972, action = [0.2]
# Episode * 562 * Avg Reward is ==> 486.26815590328664, action = [0.2]
# Episode * 563 * Avg Reward is ==> 487.13147552970605, action = [-0.2]
# Episode * 564 * Avg Reward is ==> 487.999119345666, action = [0.2]
# Episode * 565 * Avg Reward is ==> 488.8729207657232, action = [0.2]
# Episode * 566 * Avg Reward is ==> 489.75107251400107, action = [-0.2]
# Episode * 567 * Avg Reward is ==> 490.63541897544627, action = [0.2]
# Episode * 568 * Avg Reward is ==> 491.52483547866683, action = [-0.12407711]
# Episode * 569 * Avg Reward is ==> 492.41934418839014, action = [0.00082618]
# Episode * 570 * Avg Reward is ==> 493.31711028821564, action = [-0.2]
# Episode * 571 * Avg Reward is ==> 494.21628889269437, action = [-0.2]
# Episode * 572 * Avg Reward is ==> 495.11873337129646, action = [0.2]
# Episode * 573 * Avg Reward is ==> 496.02374672437315, action = [-0.07530449]
# Episode * 574 * Avg Reward is ==> 496.9310551375086, action = [-0.02966732]
# Episode * 575 * Avg Reward is ==> 497.8388019188172, action = [-0.2]
# Episode * 576 * Avg Reward is ==> 498.7488472212843, action = [0.2]
# Episode * 577 * Avg Reward is ==> 499.65933155251406, action = [-0.2]
# Episode * 578 * Avg Reward is ==> 500.57211786600215, action = [0.2]
# Episode * 579 * Avg Reward is ==> 501.4890761702482, action = [0.2]
# Episode * 580 * Avg Reward is ==> 502.4113427250028, action = [0.11980826]
# Episode * 581 * Avg Reward is ==> 503.3408126540782, action = [0.2]
# Episode * 582 * Avg Reward is ==> 504.27562687363354, action = [-0.2]
# Episode * 583 * Avg Reward is ==> 505.2139101020578, action = [-0.2]
# Episode * 584 * Avg Reward is ==> 506.15377656844777, action = [-0.2]
# Episode * 585 * Avg Reward is ==> 507.0933357210854, action = [-0.2]
# Episode * 586 * Avg Reward is ==> 508.0306979359156, action = [-0.2]
# Episode * 587 * Avg Reward is ==> 508.963980225024, action = [-0.2]
# Episode * 588 * Avg Reward is ==> 509.8913119451142, action = [-0.2]
# Episode * 589 * Avg Reward is ==> 510.8145856512308, action = [0.2]
# Episode * 590 * Avg Reward is ==> 511.7319408326489, action = [-0.2]
# Episode * 591 * Avg Reward is ==> 512.6452599118417, action = [0.2]
# Episode * 592 * Avg Reward is ==> 513.5526925106554, action = [-0.2]
# Episode * 593 * Avg Reward is ==> 514.4524063040327, action = [-0.2]
# Episode * 594 * Avg Reward is ==> 515.3425927284893, action = [-0.2]
# Episode * 595 * Avg Reward is ==> 516.2245266510911, action = [0.13318947]
# Episode * 596 * Avg Reward is ==> 517.0964239757329, action = [-0.2]
# Episode * 597 * Avg Reward is ==> 517.9601542117425, action = [0.2]
# Episode * 598 * Avg Reward is ==> 518.8148102859194, action = [-0.10431623]
# Episode * 599 * Avg Reward is ==> 519.6610740290399, action = [0.07024765]
# Episode * 600 * Avg Reward is ==> 520.4979431007471, action = [-0.11642051]
# Episode * 601 * Avg Reward is ==> 521.3236962699068, action = [-0.2]
# Episode * 602 * Avg Reward is ==> 522.140169633189, action = [0.2]
# Episode * 603 * Avg Reward is ==> 522.9456638403592, action = [-0.2]
# Episode * 604 * Avg Reward is ==> 523.7410274549181, action = [0.08854926]
# Episode * 605 * Avg Reward is ==> 524.526275060112, action = [-0.00569171]
# Episode * 606 * Avg Reward is ==> 525.3031899445674, action = [0.2]
# Episode * 607 * Avg Reward is ==> 526.0735278072699, action = [0.2]
# Episode * 608 * Avg Reward is ==> 526.8356126483419, action = [-0.2]
# Episode * 609 * Avg Reward is ==> 527.5911836765009, action = [0.2]
# Episode * 610 * Avg Reward is ==> 528.3385813821372, action = [-0.2]
# Episode * 611 * Avg Reward is ==> 529.0795284837004, action = [0.2]
# Episode * 612 * Avg Reward is ==> 529.8124978819033, action = [-0.18594956]
# Episode * 613 * Avg Reward is ==> 530.5391948015886, action = [0.2]
# Episode * 614 * Avg Reward is ==> 531.2613029826581, action = [0.2]
# Episode * 615 * Avg Reward is ==> 531.9804903885497, action = [0.2]
# Episode * 616 * Avg Reward is ==> 532.6951128645094, action = [-0.2]
# Episode * 617 * Avg Reward is ==> 533.4068297591585, action = [0.2]
# Episode * 618 * Avg Reward is ==> 534.1172903531326, action = [0.2]
# Episode * 619 * Avg Reward is ==> 534.8248538476729, action = [-0.2]
# Episode * 620 * Avg Reward is ==> 535.53116471425, action = [0.2]
# Episode * 621 * Avg Reward is ==> 536.2345869632702, action = [-0.2]
# Episode * 622 * Avg Reward is ==> 536.9334946731256, action = [-0.2]
# Episode * 623 * Avg Reward is ==> 537.6295289592913, action = [0.2]
# Episode * 624 * Avg Reward is ==> 538.3243208692567, action = [0.2]
# Episode * 625 * Avg Reward is ==> 539.0194620671222, action = [0.19563693]
# Episode * 626 * Avg Reward is ==> 539.7165804894074, action = [0.2]
# Episode * 627 * Avg Reward is ==> 540.4173110071577, action = [0.2]
# Episode * 628 * Avg Reward is ==> 541.1233011344209, action = [0.2]
# Episode * 629 * Avg Reward is ==> 541.8362167367259, action = [0.2]
# Episode * 630 * Avg Reward is ==> 542.5544373963118, action = [-0.2]
# Episode * 631 * Avg Reward is ==> 543.2796431158536, action = [0.2]
# Episode * 632 * Avg Reward is ==> 544.0101993404442, action = [-0.2]
# Episode * 633 * Avg Reward is ==> 544.7477143596186, action = [0.18962339]
# Episode * 634 * Avg Reward is ==> 545.4939053612162, action = [0.2]
# Episode * 635 * Avg Reward is ==> 546.2471290509193, action = [-0.2]
# Episode * 636 * Avg Reward is ==> 547.0057183669678, action = [-0.2]
# Episode * 637 * Avg Reward is ==> 547.7713984196821, action = [0.2]
# Episode * 638 * Avg Reward is ==> 548.5424882051663, action = [-0.2]
# Episode * 639 * Avg Reward is ==> 549.3207267758762, action = [0.2]
# Episode * 640 * Avg Reward is ==> 550.1044191857806, action = [-0.2]
# Episode * 641 * Avg Reward is ==> 550.8950619405208, action = [0.17011487]
# Episode * 642 * Avg Reward is ==> 551.6909444134837, action = [-0.2]
# Episode * 643 * Avg Reward is ==> 552.4903387631043, action = [-0.2]
# Episode * 644 * Avg Reward is ==> 553.2915056413433, action = [-0.2]
# Episode * 645 * Avg Reward is ==> 554.0961960230086, action = [0.2]
# Episode * 646 * Avg Reward is ==> 554.9061723893825, action = [0.2]
# Episode * 647 * Avg Reward is ==> 555.7232144366992, action = [0.2]
# Episode * 648 * Avg Reward is ==> 556.5455828169194, action = [-0.2]
# Episode * 649 * Avg Reward is ==> 557.3715209670518, action = [-0.2]
# Episode * 650 * Avg Reward is ==> 558.199260817631, action = [-0.2]
# Episode * 651 * Avg Reward is ==> 559.0305820648912, action = [0.2]
# Episode * 652 * Avg Reward is ==> 559.8672759115408, action = [0.2]
# Episode * 653 * Avg Reward is ==> 560.7075704526229, action = [-0.2]
# Episode * 654 * Avg Reward is ==> 561.5532664646546, action = [0.2]
# Episode * 655 * Avg Reward is ==> 562.4061819391048, action = [0.2]
# Episode * 656 * Avg Reward is ==> 563.2645392326995, action = [-0.2]
# Episode * 657 * Avg Reward is ==> 564.1265434872125, action = [-0.2]
# Episode * 658 * Avg Reward is ==> 564.9903883379437, action = [-0.2]
# Episode * 659 * Avg Reward is ==> 565.8578917763621, action = [0.2]
# Episode * 660 * Avg Reward is ==> 566.7272416696103, action = [-0.2]
# Episode * 661 * Avg Reward is ==> 567.5983696805882, action = [-0.00767055]
# Episode * 662 * Avg Reward is ==> 568.4694559463089, action = [-0.2]
# Episode * 663 * Avg Reward is ==> 569.3386807346665, action = [-0.2]
# Episode * 664 * Avg Reward is ==> 570.2042301529139, action = [-0.2]
# Episode * 665 * Avg Reward is ==> 571.0643018561404, action = [-0.2]
# Episode * 666 * Avg Reward is ==> 571.9207176121597, action = [0.2]
# Episode * 667 * Avg Reward is ==> 572.7729044196977, action = [-0.06410474]
# Episode * 668 * Avg Reward is ==> 573.6225418887655, action = [0.18556747]
# Episode * 669 * Avg Reward is ==> 574.4714302665042, action = [0.2]
# Episode * 670 * Avg Reward is ==> 575.3209583306744, action = [0.15408283]
# Episode * 671 * Avg Reward is ==> 576.1726664543633, action = [0.17086004]
# Episode * 672 * Avg Reward is ==> 577.0283610505749, action = [0.2]
# Episode * 673 * Avg Reward is ==> 577.889490040341, action = [0.15860988]
# Episode * 674 * Avg Reward is ==> 578.7578875902178, action = [0.2]
# Episode * 675 * Avg Reward is ==> 579.6354107388862, action = [0.2]
# Episode * 676 * Avg Reward is ==> 580.5202711661141, action = [-0.2]
# Episode * 677 * Avg Reward is ==> 581.4106576795447, action = [-0.2]
# Episode * 678 * Avg Reward is ==> 582.3047419231742, action = [-0.2]
# Episode * 679 * Avg Reward is ==> 583.2028176631161, action = [0.03075293]
# Episode * 680 * Avg Reward is ==> 584.1030419083315, action = [-0.2]
# ...
# Episode * 770 * Avg Reward is ==> 659.5609817685056, action = [0.2]
# Episode * 771 * Avg Reward is ==> 660.5344168900593, action = [-0.2]
# Episode * 772 * Avg Reward is ==> 661.5144375816435, action = [-0.2]
# Episode * 773 * Avg Reward is ==> 662.4991292748446, action = [-0.2]
# Episode * 774 * Avg Reward is ==> 663.4865636106981, action = [-0.2]
# Episode * 775 * Avg Reward is ==> 664.4748041481664, action = [-0.2]
# Episode * 776 * Avg Reward is ==> 665.4657922626722, action = [0.2]
# Episode * 777 * Avg Reward is ==> 666.461477411711, action = [0.2]
# Episode * 778 * Avg Reward is ==> 667.4599204602212, action = [-0.2]
# Episode * 779 * Avg Reward is ==> 668.4591741910673, action = [-0.2]
# Episode * 780 * Avg Reward is ==> 669.457159657584, action = [0.2]
# Episode * 781 * Avg Reward is ==> 670.4504426605408, action = [0.2]
# Episode * 782 * Avg Reward is ==> 671.4409749047315, action = [-0.2]
# Episode * 783 * Avg Reward is ==> 672.4307000128767, action = [-0.2]
# Episode * 784 * Avg Reward is ==> 673.4215592341017, action = [-0.2]
# Episode * 785 * Avg Reward is ==> 674.4154971524135, action = [-0.2]
# Episode * 786 * Avg Reward is ==> 675.4144673951794, action = [-0.2]
# Episode * 787 * Avg Reward is ==> 676.4085142218341, action = [-0.2]
# Episode * 788 * Avg Reward is ==> 677.3975411559119, action = [0.2]
# Episode * 789 * Avg Reward is ==> 678.3834970140507, action = [0.2]
# Episode * 790 * Avg Reward is ==> 679.3672446324945, action = [0.08823704]
# Episode * 791 * Avg Reward is ==> 680.3505572364401, action = [0.18295693]
# Episode * 792 * Avg Reward is ==> 681.33150183881, action = [-0.2]
# Episode * 793 * Avg Reward is ==> 682.3081524445631, action = [-0.2]
# Episode * 794 * Avg Reward is ==> 683.2824430888891, action = [0.2]
# Episode * 795 * Avg Reward is ==> 684.25245434093, action = [-0.2]
# Episode * 796 * Avg Reward is ==> 685.220113671692, action = [0.2]
# Episode * 797 * Avg Reward is ==> 686.1873415601455, action = [0.2]
# Episode * 798 * Avg Reward is ==> 687.152626647611, action = [-0.15725528]
# Episode * 799 * Avg Reward is ==> 688.114190820811, action = [-0.18585128]
# Episode * 800 * Avg Reward is ==> 689.0701329640436, action = [-0.2]
# Episode * 801 * Avg Reward is ==> 690.0185687630274, action = [-0.2]
# Episode * 802 * Avg Reward is ==> 690.957636413379, action = [-0.2]
# Episode * 803 * Avg Reward is ==> 691.8892643974035, action = [0.2]
# Episode * 804 * Avg Reward is ==> 692.815358687508, action = [0.2]
# Episode * 805 * Avg Reward is ==> 693.7378084546789, action = [0.2]
# Episode * 806 * Avg Reward is ==> 694.6547518945329, action = [-0.2]
# Episode * 807 * Avg Reward is ==> 695.5643440041072, action = [-0.2]
# Episode * 808 * Avg Reward is ==> 696.4684683539148, action = [0.2]
# Episode * 809 * Avg Reward is ==> 697.3652930447657, action = [-0.2]
# Episode * 810 * Avg Reward is ==> 698.2566885434001, action = [0.2]
# Episode * 811 * Avg Reward is ==> 699.1445085151375, action = [0.2]
# Episode * 812 * Avg Reward is ==> 700.0293832519669, action = [0.06752184]
# Episode * 813 * Avg Reward is ==> 700.9131506289956, action = [0.2]
# Episode * 814 * Avg Reward is ==> 701.7939795063904, action = [-0.2]
# Episode * 815 * Avg Reward is ==> 702.6737035592356, action = [0.2]
# Episode * 816 * Avg Reward is ==> 703.5541530168192, action = [0.2]
# Episode * 817 * Avg Reward is ==> 704.4334978879068, action = [-0.2]
# Episode * 818 * Avg Reward is ==> 705.30991162706, action = [-0.2]
# Episode * 819 * Avg Reward is ==> 706.1852233149683, action = [0.2]
# Episode * 820 * Avg Reward is ==> 707.0612585865249, action = [0.2]
# Episode * 821 * Avg Reward is ==> 707.9398453393046, action = [0.2]
# Episode * 822 * Avg Reward is ==> 708.8191570278691, action = [-0.2]
# Episode * 823 * Avg Reward is ==> 709.7006249002806, action = [0.1559102]
# Episode * 824 * Avg Reward is ==> 710.5860863355339, action = [0.2]
# Episode * 825 * Avg Reward is ==> 711.4737114768678, action = [-0.2]
# Episode * 826 * Avg Reward is ==> 712.3653440890428, action = [0.2]
# Episode * 827 * Avg Reward is ==> 713.2591479295321, action = [-0.2]
# Episode * 828 * Avg Reward is ==> 714.1569731488618, action = [0.2]
# Episode * 829 * Avg Reward is ==> 715.0569771187394, action = [-0.2]
# Episode * 830 * Avg Reward is ==> 715.9573104864631, action = [-0.2]
# Episode * 831 * Avg Reward is ==> 716.8574590485523, action = [-0.05522095]
# Episode * 832 * Avg Reward is ==> 717.7591962224909, action = [0.19144878]
# Episode * 833 * Avg Reward is ==> 718.6606702435839, action = [-0.2]
# Episode * 834 * Avg Reward is ==> 719.5600301581079, action = [-0.2]
# Episode * 835 * Avg Reward is ==> 720.4591272669169, action = [0.2]
# Episode * 836 * Avg Reward is ==> 721.3598120598936, action = [0.2]
# Episode * 837 * Avg Reward is ==> 722.2602338536383, action = [-0.2]
# Episode * 838 * Avg Reward is ==> 723.1585427757227, action = [-0.2]
# Episode * 839 * Avg Reward is ==> 724.0528954731676, action = [-0.2]
# Episode * 840 * Avg Reward is ==> 724.9414608209206, action = [-0.2]
# Episode * 841 * Avg Reward is ==> 725.8260914820139, action = [0.2]
# Episode * 842 * Avg Reward is ==> 726.7086278915533, action = [0.2]
# Episode * 843 * Avg Reward is ==> 727.5909039651953, action = [0.2]
# Episode * 844 * Avg Reward is ==> 728.474752807625, action = [0.2]
# Episode * 845 * Avg Reward is ==> 729.3617941378699, action = [0.17597476]
# Episode * 846 * Avg Reward is ==> 730.2529172141274, action = [0.09548238]
# Episode * 847 * Avg Reward is ==> 731.1462865856201, action = [-0.2]
# Episode * 848 * Avg Reward is ==> 732.0437522199022, action = [0.2]
# Episode * 849 * Avg Reward is ==> 732.9434721242134, action = [-0.2]
# Episode * 850 * Avg Reward is ==> 733.8435973470574, action = [-0.2]
# Episode * 851 * Avg Reward is ==> 734.7422776866804, action = [-0.2]
# Episode * 852 * Avg Reward is ==> 735.6386794976246, action = [-0.08989479]
# Episode * 853 * Avg Reward is ==> 736.5309619736889, action = [-0.2]
# Episode * 854 * Avg Reward is ==> 737.4209740513414, action = [0.2]
# Episode * 855 * Avg Reward is ==> 738.3098461222048, action = [0.12213244]
# Episode * 856 * Avg Reward is ==> 739.1957418253245, action = [-0.2]
# Episode * 857 * Avg Reward is ==> 740.0805001618659, action = [0.2]
# Episode * 858 * Avg Reward is ==> 740.9622890318053, action = [-0.2]
# Episode * 859 * Avg Reward is ==> 741.8429431753772, action = [0.2]
# Episode * 860 * Avg Reward is ==> 742.7242937956585, action = [0.2]
# Episode * 861 * Avg Reward is ==> 743.604509971678, action = [-0.2]
# Episode * 862 * Avg Reward is ==> 744.481764319622, action = [-0.2]
# Episode * 863 * Avg Reward is ==> 745.3542387013122, action = [-0.2]
# Episode * 864 * Avg Reward is ==> 746.2201299326828, action = [-0.2]
# Episode * 865 * Avg Reward is ==> 747.080626647109, action = [0.12815045]
# Episode * 866 * Avg Reward is ==> 747.937550616303, action = [0.2]
# Episode * 867 * Avg Reward is ==> 748.7927123300125, action = [0.2]
# Episode * 868 * Avg Reward is ==> 749.6443124025939, action = [-0.2]
# Episode * 869 * Avg Reward is ==> 750.4905627303681, action = [-0.2]
# Episode * 870 * Avg Reward is ==> 751.333270042428, action = [0.2]
# Episode * 871 * Avg Reward is ==> 752.1706556592299, action = [-0.2]
# Episode * 872 * Avg Reward is ==> 753.0045168857312, action = [0.2]
# Episode * 873 * Avg Reward is ==> 753.8366397449254, action = [0.2]
# Episode * 874 * Avg Reward is ==> 754.6664832953127, action = [-0.06070411]
# Episode * 875 * Avg Reward is ==> 755.4958262785252, action = [0.2]
# Episode * 876 * Avg Reward is ==> 756.3264458280119, action = [0.2]
# Episode * 877 * Avg Reward is ==> 757.1587086961177, action = [0.0408473]
# Episode * 878 * Avg Reward is ==> 757.9943989078557, action = [0.2]
# Episode * 879 * Avg Reward is ==> 758.8353114703729, action = [0.2]
# Episode * 880 * Avg Reward is ==> 759.6807621690343, action = [-0.07764533]
# Episode * 881 * Avg Reward is ==> 760.5302170912722, action = [-0.06037155]
# Episode * 882 * Avg Reward is ==> 761.3854888705583, action = [0.2]
# Episode * 883 * Avg Reward is ==> 762.2447880361764, action = [-0.2]
# Episode * 884 * Avg Reward is ==> 763.1099376098839, action = [0.2]
# Episode * 885 * Avg Reward is ==> 763.9791377326787, action = [-0.2]
# Episode * 886 * Avg Reward is ==> 764.8505758173691, action = [-0.2]
# Episode * 887 * Avg Reward is ==> 765.722432257051, action = [-0.2]
# Episode * 888 * Avg Reward is ==> 766.5965300734821, action = [0.2]
# Episode * 889 * Avg Reward is ==> 767.4710468827761, action = [-0.2]
# Episode * 890 * Avg Reward is ==> 768.3478084836729, action = [0.2]
# Episode * 891 * Avg Reward is ==> 769.2249897153041, action = [-0.2]
# Episode * 892 * Avg Reward is ==> 770.101402311865, action = [-0.12959297]
# Episode * 893 * Avg Reward is ==> 770.9788730471645, action = [0.2]
# Episode * 894 * Avg Reward is ==> 771.8560163441853, action = [-0.1512507]
# Episode * 895 * Avg Reward is ==> 772.7332672040594, action = [0.04731509]
# Episode * 896 * Avg Reward is ==> 773.6124538561628, action = [0.2]
# Episode * 897 * Avg Reward is ==> 774.4917481963298, action = [-0.2]
# Episode * 898 * Avg Reward is ==> 775.3729805808034, action = [0.2]
# Episode * 899 * Avg Reward is ==> 776.2579874103662, action = [0.2]
# Episode * 900 * Avg Reward is ==> 777.1449385660062, action = [-0.2]
# Episode * 901 * Avg Reward is ==> 778.035676381025, action = [0.2]
# Episode * 902 * Avg Reward is ==> 778.9302283731902, action = [0.00209448]
# Episode * 903 * Avg Reward is ==> 779.82797770052, action = [-0.06721464]
# Episode * 904 * Avg Reward is ==> 780.7298111730656, action = [0.0946534]
# Episode * 905 * Avg Reward is ==> 781.6353551208189, action = [-0.04098895]
# Episode * 906 * Avg Reward is ==> 782.5427579151757, action = [-0.2]
# Episode * 907 * Avg Reward is ==> 783.4501622144311, action = [-0.2]
# Episode * 908 * Avg Reward is ==> 784.3586177950026, action = [0.11243518]
# Episode * 909 * Avg Reward is ==> 785.2671198885738, action = [-0.10759708]
# Episode * 910 * Avg Reward is ==> 786.1738099801875, action = [-0.2]
# Episode * 911 * Avg Reward is ==> 787.0768351205658, action = [-0.2]
# Episode * 912 * Avg Reward is ==> 787.974353634588, action = [-0.2]
# Episode * 913 * Avg Reward is ==> 788.8645408297683, action = [-0.2]
# Episode * 914 * Avg Reward is ==> 789.7492607415253, action = [0.2]
# Episode * 915 * Avg Reward is ==> 790.6270345500113, action = [-0.16323134]
# Episode * 916 * Avg Reward is ==> 791.4960700952736, action = [-0.2]
# Episode * 917 * Avg Reward is ==> 792.3582215049249, action = [0.2]
# Episode * 918 * Avg Reward is ==> 793.2153212545257, action = [0.2]
# Episode * 919 * Avg Reward is ==> 794.0691858760617, action = [0.2]
# Episode * 920 * Avg Reward is ==> 794.9180232095799, action = [-0.2]
# Episode * 921 * Avg Reward is ==> 795.7636410608421, action = [0.2]
# Episode * 922 * Avg Reward is ==> 796.6042559961193, action = [-0.2]
# Episode * 923 * Avg Reward is ==> 797.4416670949491, action = [0.2]
# Episode * 924 * Avg Reward is ==> 798.2776632017724, action = [0.2]
# Episode * 925 * Avg Reward is ==> 799.1140286344101, action = [0.2]
# Episode * 926 * Avg Reward is ==> 799.9518602774172, action = [0.12237516]
# Episode * 927 * Avg Reward is ==> 800.7893731672754, action = [-0.2]
# Episode * 928 * Avg Reward is ==> 801.6247833595818, action = [-0.2]
# Episode * 929 * Avg Reward is ==> 802.4563136375261, action = [-0.2]
# Episode * 930 * Avg Reward is ==> 803.2830622171598, action = [-0.10216351]
# Episode * 931 * Avg Reward is ==> 804.1068125020535, action = [0.2]
# Episode * 932 * Avg Reward is ==> 804.9293382377674, action = [0.2]
# Episode * 933 * Avg Reward is ==> 805.7524092203292, action = [0.2]
# Episode * 934 * Avg Reward is ==> 806.5769567690324, action = [0.10464981]
# Episode * 935 * Avg Reward is ==> 807.4047561687609, action = [0.2]
# Episode * 936 * Avg Reward is ==> 808.2340363679824, action = [-0.2]
# Episode * 937 * Avg Reward is ==> 809.066577728021, action = [0.2]
# Episode * 938 * Avg Reward is ==> 809.9006041209045, action = [-0.2]
# Episode * 939 * Avg Reward is ==> 810.7343346582395, action = [-0.2]
# Episode * 940 * Avg Reward is ==> 811.569551288157, action = [0.2]
# Episode * 941 * Avg Reward is ==> 812.4080407192092, action = [0.2]
# Episode * 942 * Avg Reward is ==> 813.2480204761957, action = [-0.2]
# Episode * 943 * Avg Reward is ==> 814.0877033234946, action = [-0.2]
# Episode * 944 * Avg Reward is ==> 814.92530297354, action = [-0.2]
# Episode * 945 * Avg Reward is ==> 815.7590397953005, action = [-0.2]
# Episode * 946 * Avg Reward is ==> 816.5899856930264, action = [0.11907464]
# Episode * 947 * Avg Reward is ==> 817.419921596456, action = [0.2]
# Episode * 948 * Avg Reward is ==> 818.2470729502216, action = [-0.2]
# Episode * 949 * Avg Reward is ==> 819.0696741506082, action = [-0.2]
# Episode * 950 * Avg Reward is ==> 819.8859742540305, action = [-0.2]
# Episode * 951 * Avg Reward is ==> 820.6942426855113, action = [-0.2]
# Episode * 952 * Avg Reward is ==> 821.4927749471588, action = [-0.2]
# Episode * 953 * Avg Reward is ==> 822.2833636449568, action = [0.2]
# Episode * 954 * Avg Reward is ==> 823.0677753078043, action = [0.2]
# Episode * 955 * Avg Reward is ==> 823.8460998884219, action = [0.00758737]
# Episode * 956 * Avg Reward is ==> 824.6200763870874, action = [0.2]
# Episode * 957 * Avg Reward is ==> 825.3914293619584, action = [0.2]
# Episode * 958 * Avg Reward is ==> 826.1618746375505, action = [0.2]
# Episode * 959 * Avg Reward is ==> 826.9298497135272, action = [-0.18256]
# Episode * 960 * Avg Reward is ==> 827.6970663351252, action = [0.2]
# Episode * 961 * Avg Reward is ==> 828.4652337143837, action = [0.2]
# Episode * 962 * Avg Reward is ==> 829.2326425442861, action = [-0.2]
# Episode * 963 * Avg Reward is ==> 829.9975860510128, action = [-0.2]
# Episode * 964 * Avg Reward is ==> 830.7617726022044, action = [0.2]
# Episode * 965 * Avg Reward is ==> 831.5269080323042, action = [0.2]
# Episode * 966 * Avg Reward is ==> 832.2912864118915, action = [-0.2]
# Episode * 967 * Avg Reward is ==> 833.056613789438, action = [0.2]
# Episode * 968 * Avg Reward is ==> 833.8211840214949, action = [-0.2]
# Episode * 969 * Avg Reward is ==> 834.5867033705617, action = [0.2]
# Episode * 970 * Avg Reward is ==> 835.3514654791619, action = [-0.2]
# Episode * 971 * Avg Reward is ==> 836.1171768238228, action = [0.2]
# Episode * 972 * Avg Reward is ==> 836.8855470563524, action = [0.2]
# Episode * 973 * Avg Reward is ==> 837.6582947123172, action = [0.2]
# Episode * 974 * Avg Reward is ==> 838.4347696746484, action = [-0.07663096]
# Episode * 975 * Avg Reward is ==> 839.2167050026083, action = [0.2]
# Episode * 976 * Avg Reward is ==> 840.0054237459033, action = [0.15014747]
# Episode * 977 * Avg Reward is ==> 840.7992161768478, action = [-0.2]
# Episode * 978 * Avg Reward is ==> 841.5998431501172, action = [0.2]
# Episode * 979 * Avg Reward is ==> 842.4055819081402, action = [-0.2]
# Episode * 980 * Avg Reward is ==> 843.2146930027565, action = [-0.2]
# Episode * 981 * Avg Reward is ==> 844.0254260036938, action = [-0.2]
# Episode * 982 * Avg Reward is ==> 844.8395417656275, action = [0.2]
# Episode * 983 * Avg Reward is ==> 845.6552844397033, action = [-0.2]
# Episode * 984 * Avg Reward is ==> 846.4725462363282, action = [-0.01232547]
# Episode * 985 * Avg Reward is ==> 847.2930947397514, action = [0.2]
# Episode * 986 * Avg Reward is ==> 848.1151668319186, action = [-0.2]
# Episode * 987 * Avg Reward is ==> 848.9405352795641, action = [0.2]
# Episode * 988 * Avg Reward is ==> 849.7674317821487, action = [-0.2]
# Episode * 989 * Avg Reward is ==> 850.5976342888916, action = [0.2]
# Episode * 990 * Avg Reward is ==> 851.4293693167688, action = [-0.2]
# Episode * 991 * Avg Reward is ==> 852.2608584632675, action = [-0.2]
# Episode * 992 * Avg Reward is ==> 853.093254855347, action = [0.12911373]
# Episode * 993 * Avg Reward is ==> 853.9247791344139, action = [-0.2]
# Episode * 994 * Avg Reward is ==> 854.7572106782231, action = [0.2]
# Episode * 995 * Avg Reward is ==> 855.592331775139, action = [0.2]
# Episode * 996 * Avg Reward is ==> 856.4319333326127, action = [0.2]
# Episode * 997 * Avg Reward is ==> 857.2778205856607, action = [0.2]
# Episode * 998 * Avg Reward is ==> 858.1282170487183, action = [-0.2]
# Episode * 999 * Avg Reward is ==> 858.9813319086561, action = [-0.2]

# %%
x_ball = []
for observation in obs_list: 
   x =  observation[1]
   x_ball.append(x)

# %%
plt.plot(x_ball)
plt.xlabel("Episode")
plt.ylabel("Ball Postion")
plt.title("PPO ball position control")
# Out:
# Text(0.5, 1.0, 'PPO ball position control')

# %% [markdown]
# DDPG

# %%
import sys
import os
import gym
import torch
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
sys.path.append('ballbeam-gym')
from ballbeam_gym.envs.setpoint import BallBeamSetpointEnv

kwargs = {'timestep': 0.05, 
          'setpoint': 2,
          'beam_length': 5.0,
          'max_angle': 0.2,
          'init_velocity': 0.0,
          'action_mode': 'continuous'}

env = BallBeamSetpointEnv(**kwargs)

n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=10000, log_interval=10)

ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []
episodic_reward = 0
obs_list = []
obs = env.reset()
for ep in range(1000):
    obs = obs.astype(np.float)
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    #env.render()
    obs_list.append(obs)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.4     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 35       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 404      |
# | train/             |          |
# |    actor_loss      | -1.04    |
# |    critic_loss     | 0.000135 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 273      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | 20.1     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 33       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 724      |
# | train/             |          |
# |    actor_loss      | -1.63    |
# |    critic_loss     | 0.000672 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 593      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | 19.3     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 29       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 1044     |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 0.000813 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 913      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.1     |
# |    ep_rew_mean     | 18.8     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 29       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 1364     |
# | train/             |          |
# |    actor_loss      | -2.87    |
# |    critic_loss     | 0.00245  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1233     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.7     |
# |    ep_rew_mean     | 18.5     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 29       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 1684     |
# | train/             |          |
# |    actor_loss      | -3.36    |
# |    critic_loss     | 0.000677 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1553     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.4     |
# |    ep_rew_mean     | 18.4     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 27       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 2004     |
# | train/             |          |
# |    actor_loss      | -3.92    |
# |    critic_loss     | 0.00174  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1873     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.2     |
# |    ep_rew_mean     | 18.3     |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 27       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 2324     |
# | train/             |          |
# |    actor_loss      | -4.28    |
# |    critic_loss     | 0.00372  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2193     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33       |
# |    ep_rew_mean     | 18.2     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 27       |
# |    time_elapsed    | 94       |
# |    total_timesteps | 2644     |
# | train/             |          |
# |    actor_loss      | -4.68    |
# |    critic_loss     | 0.00269  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2513     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.9     |
# |    ep_rew_mean     | 18.1     |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 21       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 2964     |
# | train/             |          |
# |    actor_loss      | -5.02    |
# |    critic_loss     | 0.00117  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2833     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | 18       |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 19       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 3284     |
# | train/             |          |
# |    actor_loss      | -5.29    |
# |    critic_loss     | 0.00147  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3153     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 17       |
# |    time_elapsed    | 207      |
# |    total_timesteps | 3604     |
# | train/             |          |
# |    actor_loss      | -5.59    |
# |    critic_loss     | 0.00297  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3473     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 14       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 3925     |
# | train/             |          |
# |    actor_loss      | -5.72    |
# |    critic_loss     | 0.000782 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3794     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 9        |
# |    time_elapsed    | 426      |
# |    total_timesteps | 4245     |
# | train/             |          |
# |    actor_loss      | -5.94    |
# |    critic_loss     | 0.000839 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4114     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 9        |
# |    time_elapsed    | 475      |
# |    total_timesteps | 4565     |
# | train/             |          |
# |    actor_loss      | -6.07    |
# |    critic_loss     | 0.00079  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4434     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.6     |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 9        |
# |    time_elapsed    | 501      |
# |    total_timesteps | 4885     |
# | train/             |          |
# |    actor_loss      | -6.14    |
# |    critic_loss     | 0.000456 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4754     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 9        |
# |    time_elapsed    | 533      |
# |    total_timesteps | 5205     |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 0.000324 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5074     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 9        |
# |    time_elapsed    | 580      |
# |    total_timesteps | 5526     |
# | train/             |          |
# |    actor_loss      | -6.32    |
# |    critic_loss     | 0.000215 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5395     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 9        |
# |    time_elapsed    | 593      |
# |    total_timesteps | 5847     |
# | train/             |          |
# |    actor_loss      | -6.34    |
# |    critic_loss     | 0.000529 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5716     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 10       |
# |    time_elapsed    | 608      |
# |    total_timesteps | 6168     |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 0.000764 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6037     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 10       |
# |    time_elapsed    | 626      |
# |    total_timesteps | 6488     |
# | train/             |          |
# |    actor_loss      | -6.46    |
# |    critic_loss     | 0.00125  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6357     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 10       |
# |    time_elapsed    | 650      |
# |    total_timesteps | 6807     |
# | train/             |          |
# |    actor_loss      | -6.52    |
# |    critic_loss     | 0.00111  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6676     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 10       |
# |    time_elapsed    | 673      |
# |    total_timesteps | 7128     |
# | train/             |          |
# |    actor_loss      | -6.5     |
# |    critic_loss     | 0.000683 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6997     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 10       |
# |    time_elapsed    | 694      |
# |    total_timesteps | 7448     |
# | train/             |          |
# |    actor_loss      | -6.58    |
# |    critic_loss     | 0.000235 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7317     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 10       |
# |    time_elapsed    | 712      |
# |    total_timesteps | 7768     |
# | train/             |          |
# |    actor_loss      | -6.45    |
# |    critic_loss     | 0.000548 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7637     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 10       |
# |    time_elapsed    | 756      |
# |    total_timesteps | 8088     |
# | train/             |          |
# |    actor_loss      | -6.53    |
# |    critic_loss     | 0.000414 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7957     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 10       |
# |    time_elapsed    | 809      |
# |    total_timesteps | 8408     |
# | train/             |          |
# |    actor_loss      | -6.55    |
# |    critic_loss     | 0.000313 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8277     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 10       |
# |    time_elapsed    | 833      |
# |    total_timesteps | 8728     |
# | train/             |          |
# |    actor_loss      | -6.46    |
# |    critic_loss     | 0.00112  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8597     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 10       |
# |    time_elapsed    | 869      |
# |    total_timesteps | 9048     |
# | train/             |          |
# |    actor_loss      | -6.5     |
# |    critic_loss     | 0.000835 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8917     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 10       |
# |    time_elapsed    | 893      |
# |    total_timesteps | 9368     |
# | train/             |          |
# |    actor_loss      | -6.49    |
# |    critic_loss     | 0.000772 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9237     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 10       |
# |    time_elapsed    | 919      |
# |    total_timesteps | 9688     |
# | train/             |          |
# |    actor_loss      | -6.56    |
# |    critic_loss     | 0.000321 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9557     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 10       |
# |    time_elapsed    | 931      |
# |    total_timesteps | 10008    |
# | train/             |          |
# |    actor_loss      | -6.47    |
# |    critic_loss     | 0.00114  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9877     |
# ---------------------------------
# C:\Users\NOTEBO~1\AppData\Local\Temp/ipykernel_57452/3409308275.py:37: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   obs = obs.astype(np.float)

# %%
x_ball = []
setpoint_list = []
for observation in obs_list: 
   x =  observation[1]
   set_point = observation[3]
   x_ball.append(x)
   setpoint_list.append(set_point)

# %%
plt.plot(x_ball)
plt.plot(setpoint_list)
plt.xlabel("Episode")
plt.ylabel("Ball Postion")
plt.title("DDPG ball position control")
# Out:
# Text(0.5, 1.0, 'DDPG ball position control')

# %%
import sys
import os
import gym
import torch
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import A2C

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
sys.path.append('ballbeam-gym')
from ballbeam_gym.envs.setpoint import BallBeamSetpointEnv

timestep = 0.05
kwargs = {'timestep': timestep, 
          'setpoint': 2,
          'beam_length': 5.0,
          'max_angle': 0.2,
          'init_velocity': 0.0,
          'action_mode': 'continuous'}

env = BallBeamSetpointEnv(**kwargs)

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=50000)

obs = env.reset()
obs_list =[]
for ep in range(1000):
    obs = obs.astype(np.float)
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    obs_list.append(obs)
    #env.render()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 77.7     |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.0169   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -15.8    |
# |    std                | 0.989    |
# |    value_loss         | 172      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.8     |
# |    ep_rew_mean        | 75.6     |
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | -0.0018  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 2.54     |
# |    std                | 0.997    |
# |    value_loss         | 2.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.6     |
# |    ep_rew_mean        | 70.8     |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.00069  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 2.21     |
# |    std                | 0.997    |
# |    value_loss         | 2.99     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 95.2      |
# |    ep_rew_mean        | 69.8      |
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 400       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -0.000333 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.729     |
# |    std                | 0.997     |
# |    value_loss         | 0.483     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94       |
# |    ep_rew_mean        | 69.3     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00215  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.81     |
# |    std                | 0.995    |
# |    value_loss         | 2.38     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.1     |
# |    ep_rew_mean        | 70.4     |
# | time/                 |          |
# |    fps                | 226      |
# |    iterations         | 600      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.00334  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.604    |
# |    std                | 0.998    |
# |    value_loss         | 0.374    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.9     |
# |    ep_rew_mean        | 68.3     |
# | time/                 |          |
# |    fps                | 209      |
# |    iterations         | 700      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.000109 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.53     |
# |    std                | 1.01     |
# |    value_loss         | 2.38     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.5     |
# |    ep_rew_mean        | 68.9     |
# | time/                 |          |
# |    fps                | 223      |
# |    iterations         | 800      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.000288 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.48     |
# |    std                | 0.997    |
# |    value_loss         | 1.84     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.8     |
# |    ep_rew_mean        | 68.8     |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 900      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00455  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.831    |
# |    std                | 0.992    |
# |    value_loss         | 0.271    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94       |
# |    ep_rew_mean        | 69.5     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 5.66e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.12     |
# |    std                | 0.985    |
# |    value_loss         | 1.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.4     |
# |    ep_rew_mean        | 69.9     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1100     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.000182 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.64     |
# |    std                | 0.99     |
# |    value_loss         | 2        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.8     |
# |    ep_rew_mean        | 69.6     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00452  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 1.28     |
# |    std                | 0.992    |
# |    value_loss         | 1.56     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.1     |
# |    ep_rew_mean        | 70.2     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 1300     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00388  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.18     |
# |    std                | 0.993    |
# |    value_loss         | 0.961    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.8     |
# |    ep_rew_mean        | 69.5     |
# | time/                 |          |
# |    fps                | 289      |
# |    iterations         | 1400     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -309     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 3.32     |
# |    std                | 0.992    |
# |    value_loss         | 8.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.1     |
# |    ep_rew_mean        | 69.8     |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 1500     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.808    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0264   |
# |    std                | 0.99     |
# |    value_loss         | 0.00243  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.3     |
# |    ep_rew_mean        | 70.7     |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 1600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.00246  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.86     |
# |    std                | 0.983    |
# |    value_loss         | 0.363    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.5     |
# |    ep_rew_mean        | 71.6     |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 1700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -0.0141  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.787    |
# |    std                | 0.989    |
# |    value_loss         | 0.346    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.7     |
# |    ep_rew_mean        | 72.7     |
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 1800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -0.00794 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.831    |
# |    std                | 0.994    |
# |    value_loss         | 0.474    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 73.5     |
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 1900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.000478 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -89      |
# |    std                | 0.99     |
# |    value_loss         | 3.62e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 73.8     |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 2000     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00403  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0308   |
# |    std                | 0.99     |
# |    value_loss         | 0.000452 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.2     |
# |    ep_rew_mean        | 71.6     |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 2100     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.00016  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -1.51    |
# |    std                | 1.01     |
# |    value_loss         | 1.46     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.7     |
# |    ep_rew_mean        | 66.3     |
# | time/                 |          |
# |    fps                | 351      |
# |    iterations         | 2200     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.000141 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -1.35    |
# |    std                | 1.01     |
# |    value_loss         | 1.79     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.4     |
# |    ep_rew_mean        | 63.9     |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 2300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 8.63e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -2.15    |
# |    std                | 1.01     |
# |    value_loss         | 1.19     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.3     |
# |    ep_rew_mean        | 62.1     |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 2400     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 1.27e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -1.21    |
# |    std                | 1.01     |
# |    value_loss         | 1.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.8     |
# |    ep_rew_mean        | 60.4     |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 2500     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.000184 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.594   |
# |    std                | 1.01     |
# |    value_loss         | 0.408    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.3     |
# |    ep_rew_mean        | 58.7     |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 2600     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 9.01e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.891   |
# |    std                | 1.01     |
# |    value_loss         | 0.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.9     |
# |    ep_rew_mean        | 57.1     |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 2700     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.000845 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.177   |
# |    std                | 1.01     |
# |    value_loss         | 0.0182   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.7     |
# |    ep_rew_mean        | 54.4     |
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 2800     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 6.74e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -1.26    |
# |    std                | 1.01     |
# |    value_loss         | 1.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.3     |
# |    ep_rew_mean        | 51       |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 2900     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | -2.5e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -33.5    |
# |    std                | 1.01     |
# |    value_loss         | 1.92e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 3000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.000118 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 1.09     |
# |    std                | 1        |
# |    value_loss         | 0.704    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 51.4     |
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 3100     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 6.42e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 1.01     |
# |    std                | 1.01     |
# |    value_loss         | 0.862    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 51.3     |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 3200     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 2.07e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.923    |
# |    std                | 1        |
# |    value_loss         | 0.586    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 50.8     |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 3300     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 5.48e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 1.41     |
# |    std                | 1.01     |
# |    value_loss         | 0.942    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 50       |
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 3400     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.185    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.808    |
# |    std                | 1.01     |
# |    value_loss         | 0.667    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 49.8     |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 3500     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.00912  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.757    |
# |    std                | 1        |
# |    value_loss         | 0.651    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 49.7     |
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 3600     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | -0.0105  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.282    |
# |    std                | 1.01     |
# |    value_loss         | 0.0533   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 80.6     |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 3700     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.00839  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 1.16     |
# |    std                | 0.993    |
# |    value_loss         | 0.528    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.7     |
# |    ep_rew_mean        | 54.3     |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3800     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.701    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.33     |
# |    std                | 0.995    |
# |    value_loss         | 0.0319   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.6     |
# |    ep_rew_mean        | 57.5     |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 3900     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.0159   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.627    |
# |    std                | 0.987    |
# |    value_loss         | 0.17     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 89.3      |
# |    ep_rew_mean        | 60.7      |
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 4000      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 0.35      |
# |    std                | 0.987     |
# |    value_loss         | 0.119     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.8     |
# |    ep_rew_mean        | 63.5     |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 4100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.644    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0214  |
# |    std                | 0.992    |
# |    value_loss         | 0.00041  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.5     |
# |    ep_rew_mean        | 65.7     |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 4200     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -1.2     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.35     |
# |    std                | 0.99     |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.7     |
# |    ep_rew_mean        | 68.5     |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 4300     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.0402   |
# |    std                | 0.983    |
# |    value_loss         | 0.000835 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.1     |
# |    ep_rew_mean        | 70.7     |
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 4400     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -0.00539 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.363   |
# |    std                | 0.992    |
# |    value_loss         | 0.071    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.8     |
# |    ep_rew_mean        | 72.7     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 4500     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -0.0196  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0509   |
# |    std                | 0.991    |
# |    value_loss         | 0.00124  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 94.4     |
# |    ep_rew_mean        | 74.8     |
# | time/                 |          |
# |    fps                | 386      |
# |    iterations         | 4600     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | -0.0101  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.333    |
# |    std                | 0.979    |
# |    value_loss         | 0.111    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.7     |
# |    ep_rew_mean        | 77.7     |
# | time/                 |          |
# |    fps                | 389      |
# |    iterations         | 4700     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | -1.53    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.216    |
# |    std                | 0.985    |
# |    value_loss         | 0.0238   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 98       |
# |    ep_rew_mean        | 81       |
# | time/                 |          |
# |    fps                | 390      |
# |    iterations         | 4800     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.499    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0254  |
# |    std                | 0.983    |
# |    value_loss         | 0.000268 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 83.7     |
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 4900     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.00202  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -32.2    |
# |    std                | 0.969    |
# |    value_loss         | 3.08e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 84.6     |
# | time/                 |          |
# |    fps                | 395      |
# |    iterations         | 5000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.00128  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.392   |
# |    std                | 0.972    |
# |    value_loss         | 0.0901   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 83.9     |
# | time/                 |          |
# |    fps                | 398      |
# |    iterations         | 5100     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.00521  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.477   |
# |    std                | 0.982    |
# |    value_loss         | 0.0564   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 84.3     |
# | time/                 |          |
# |    fps                | 401      |
# |    iterations         | 5200     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.0223   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.118    |
# |    std                | 0.979    |
# |    value_loss         | 0.00332  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 85       |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 5300     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.00625  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.311    |
# |    std                | 0.985    |
# |    value_loss         | 0.0572   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 85.8     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 5400     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 9.22e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.352   |
# |    std                | 0.978    |
# |    value_loss         | 0.111    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 99        |
# |    ep_rew_mean        | 85        |
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 5500      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.39     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -0.577    |
# |    std                | 0.975     |
# |    value_loss         | 0.322     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 99        |
# |    ep_rew_mean        | 84.5      |
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 5600      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.4      |
# |    explained_variance | -6.46e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.275    |
# |    std                | 0.978     |
# |    value_loss         | 0.0549    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 84.8     |
# | time/                 |          |
# |    fps                | 413      |
# |    iterations         | 5700     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.0129  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.217    |
# |    std                | 0.963    |
# |    value_loss         | 0.038    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 85       |
# | time/                 |          |
# |    fps                | 415      |
# |    iterations         | 5800     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -0.0111  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.284    |
# |    std                | 0.947    |
# |    value_loss         | 0.0429   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 99        |
# |    ep_rew_mean        | 85.3      |
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 5900      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | -0.000143 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -0.587    |
# |    std                | 0.952     |
# |    value_loss         | 0.279     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 84.6     |
# | time/                 |          |
# |    fps                | 420      |
# |    iterations         | 6000     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.00066  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.354   |
# |    std                | 0.954    |
# |    value_loss         | 0.125    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99       |
# |    ep_rew_mean        | 83       |
# | time/                 |          |
# |    fps                | 422      |
# |    iterations         | 6100     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -1.5     |
# |    std                | 0.972    |
# |    value_loss         | 2.65     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.6     |
# |    ep_rew_mean        | 75.2     |
# | time/                 |          |
# |    fps                | 423      |
# |    iterations         | 6200     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.00604  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.153   |
# |    std                | 0.972    |
# |    value_loss         | 0.0193   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.6     |
# |    ep_rew_mean        | 68.8     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 6300     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 8e-05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -1.01    |
# |    std                | 0.98     |
# |    value_loss         | 0.662    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.8     |
# |    ep_rew_mean        | 62.9     |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 6400     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.00116  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.371   |
# |    std                | 0.98     |
# |    value_loss         | 0.0591   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74       |
# |    ep_rew_mean        | 52.6     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 6500     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -0.00135 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.335    |
# |    std                | 0.991    |
# |    value_loss         | 0.0425   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 63.3     |
# |    ep_rew_mean        | 41.9     |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 6600     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 8.7e-06  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -1.69    |
# |    std                | 0.998    |
# |    value_loss         | 1.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.4     |
# |    ep_rew_mean        | 33.2     |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 6700     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 5.48e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -2.42    |
# |    std                | 0.997    |
# |    value_loss         | 2.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 52       |
# |    ep_rew_mean        | 29.7     |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 6800     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 3.64e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -1.73    |
# |    std                | 0.997    |
# |    value_loss         | 1.84     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 50.1      |
# |    ep_rew_mean        | 25.4      |
# | time/                 |           |
# |    fps                | 435       |
# |    iterations         | 6900      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -6.56e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -0.731    |
# |    std                | 1.01      |
# |    value_loss         | 0.643     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50.1     |
# |    ep_rew_mean        | 23.9     |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 7000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.00011  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.00722  |
# |    std                | 1.01     |
# |    value_loss         | 1.54e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50.1     |
# |    ep_rew_mean        | 23.9     |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 7100     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.898   |
# |    std                | 1.01     |
# |    value_loss         | 0.439    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 52.3     |
# |    ep_rew_mean        | 25.2     |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 7200     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | -0.0001  |
# |    learning_rate      | 0.0007   |
# ...
# |    std                | 1.02     |
# |    value_loss         | 0.0795   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66.4     |
# |    ep_rew_mean        | 37.8     |
# | time/                 |          |
# |    fps                | 444      |
# |    iterations         | 7800     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | -6.2e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -68.1    |
# |    std                | 1.02     |
# |    value_loss         | 3.98e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 66.4      |
# |    ep_rew_mean        | 37.8      |
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7900      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -5.28e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 0.131     |
# |    std                | 1.02      |
# |    value_loss         | 0.0231    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66.5     |
# |    ep_rew_mean        | 37.8     |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 8000     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 1.57e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | -0.722   |
# |    std                | 1.02     |
# |    value_loss         | 0.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 62.2     |
# |    ep_rew_mean        | 36.6     |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 8100     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -63.5    |
# |    std                | 1.02     |
# |    value_loss         | 3.56e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.2     |
# |    ep_rew_mean        | 33       |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 8200     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -1.45    |
# |    std                | 1.02     |
# |    value_loss         | 1.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.6     |
# |    ep_rew_mean        | 32.5     |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 8300     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 0.19     |
# |    std                | 1.03     |
# |    value_loss         | 0.0164   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 53.6      |
# |    ep_rew_mean        | 33        |
# | time/                 |           |
# |    fps                | 450       |
# |    iterations         | 8400      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -41       |
# |    std                | 1.03      |
# |    value_loss         | 2.01e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.6     |
# |    ep_rew_mean        | 34       |
# | time/                 |          |
# |    fps                | 452      |
# |    iterations         | 8500     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 3.24e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.588    |
# |    std                | 1.02     |
# |    value_loss         | 0.441    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.6     |
# |    ep_rew_mean        | 34.7     |
# | time/                 |          |
# |    fps                | 453      |
# |    iterations         | 8600     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | 0.501    |
# |    std                | 1        |
# |    value_loss         | 0.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.6     |
# |    ep_rew_mean        | 35       |
# | time/                 |          |
# |    fps                | 454      |
# |    iterations         | 8700     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 0.0258   |
# |    std                | 0.998    |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.6     |
# |    ep_rew_mean        | 35.8     |
# | time/                 |          |
# |    fps                | 455      |
# |    iterations         | 8800     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | -0.301   |
# |    std                | 0.997    |
# |    value_loss         | 0.0813   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 56.3      |
# |    ep_rew_mean        | 37.6      |
# | time/                 |           |
# |    fps                | 455       |
# |    iterations         | 8900      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -1.19     |
# |    std                | 1.01      |
# |    value_loss         | 1.18      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.6     |
# |    ep_rew_mean        | 38.8     |
# | time/                 |          |
# |    fps                | 456      |
# |    iterations         | 9000     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.0917  |
# |    std                | 1        |
# |    value_loss         | 0.00695  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.6     |
# |    ep_rew_mean        | 38.8     |
# | time/                 |          |
# |    fps                | 457      |
# |    iterations         | 9100     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | -0.689   |
# |    std                | 1        |
# |    value_loss         | 0.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.8     |
# |    ep_rew_mean        | 38.8     |
# | time/                 |          |
# |    fps                | 458      |
# |    iterations         | 9200     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 0.514    |
# |    std                | 0.997    |
# |    value_loss         | 0.215    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.2     |
# |    ep_rew_mean        | 38.7     |
# | time/                 |          |
# |    fps                | 459      |
# |    iterations         | 9300     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | 0.486    |
# |    std                | 0.997    |
# |    value_loss         | 0.261    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.9     |
# |    ep_rew_mean        | 36.5     |
# | time/                 |          |
# |    fps                | 459      |
# |    iterations         | 9400     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | 0.946    |
# |    std                | 0.995    |
# |    value_loss         | 0.244    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.9     |
# |    ep_rew_mean        | 26.3     |
# | time/                 |          |
# |    fps                | 459      |
# |    iterations         | 9500     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 47500    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9499     |
# |    policy_loss        | -0.844   |
# |    std                | 0.994    |
# |    value_loss         | 0.808    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39       |
# |    ep_rew_mean        | 21       |
# | time/                 |          |
# |    fps                | 459      |
# |    iterations         | 9600     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | -1.09    |
# |    std                | 1        |
# |    value_loss         | 0.391    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.4     |
# |    ep_rew_mean        | 20.2     |
# | time/                 |          |
# |    fps                | 460      |
# |    iterations         | 9700     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | -0.52    |
# |    std                | 1.02     |
# |    value_loss         | 0.114    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.2     |
# |    ep_rew_mean        | 21.5     |
# | time/                 |          |
# |    fps                | 461      |
# |    iterations         | 9800     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 0.392    |
# |    std                | 1.02     |
# |    value_loss         | 0.0829   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 43.5      |
# |    ep_rew_mean        | 24.8      |
# | time/                 |           |
# |    fps                | 460       |
# |    iterations         | 9900      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | -6.06e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | 0.338     |
# |    std                | 1.02      |
# |    value_loss         | 0.0598    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.7      |
# |    ep_rew_mean        | 28.3      |
# | time/                 |           |
# |    fps                | 460       |
# |    iterations         | 10000     |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | -1.45e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 1.03      |
# |    std                | 1.01      |
# |    value_loss         | 1.07      |
# -------------------------------------
# C:\Users\NOTEBO~1\AppData\Local\Temp/ipykernel_57452/2171594426.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   obs = obs.astype(np.float)

# %%
x_ball = []
setpoint_list = []
for observation in obs_list: 
   x =  observation[1]
   set_point = observation[3]
   x_ball.append(x)
   setpoint_list.append(set_point)

timestep = 0.05
seconds_list = []
for i in range(len(x_ball)):
    seconds = i*timestep
    seconds_list.append(seconds)

# %%
plt.figure(figsize =(14,8))
plt.plot(seconds_list,x_ball)
plt.plot(seconds_list,setpoint_list)
plt.legend(['posicao','setpoint'])
plt.xlabel("Seconds")
plt.ylabel("Postion")
plt.title("A2C ball position control")
# Out:
# Text(0.5, 1.0, 'A2C ball position control')

# %%
model.save('model_a2c')

# %%
model2 = A2C.load('model_a2c.zip')

# %%
import sys
import os
import gym
import torch
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import DQN

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
sys.path.append('ballbeam-gym')
from ballbeam_gym.envs.setpoint import BallBeamSetpointEnv

kwargs = {'timestep': 0.05, 
          'setpoint': 2,
          'beam_length': 5.0,
          'max_angle': 0.2,
          'init_velocity': 0.0,
          'action_mode': 'discrete'}

env = BallBeamSetpointEnv(**kwargs)

model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000, log_interval=4)

obs = env.reset()
obs_list = []
for ep in range(1000):
    obs = obs.astype(np.float)
    action, _states = model.predict(obs,deterministic=True)
    obs, rewards, dones, info = env.step(action)
    obs_list.append(obs)
    #env.render()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.8     |
# |    ep_rew_mean      | 45.3     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 15013    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 271      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 58.6     |
# |    ep_rew_mean      | 40.6     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 15607    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 469      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57       |
# |    ep_rew_mean      | 40       |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 15888    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 684      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.2     |
# |    ep_rew_mean      | 38.6     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 16037    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 883      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.2     |
# |    ep_rew_mean      | 37.8     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 16182    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.8     |
# |    ep_rew_mean      | 36.7     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 16027    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51       |
# |    ep_rew_mean      | 34.8     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 15846    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.5     |
# |    ep_rew_mean      | 35.5     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 15989    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.1     |
# |    ep_rew_mean      | 34.8     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 15971    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 15747    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.7     |
# |    ep_rew_mean      | 34.7     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 15476    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.8     |
# |    ep_rew_mean      | 34.7     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 15513    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.6     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 15497    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.5     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 15496    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.1     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 15376    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.6     |
# |    ep_rew_mean      | 34       |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 15424    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.1     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 15425    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 35       |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 15477    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 35.2     |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 15428    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 35.6     |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 15476    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 35       |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 15457    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 34.9     |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 15447    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 34.9     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 15445    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 35       |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 15370    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.3     |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 15373    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 34.9     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 15382    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.3     |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 15405    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.9     |
# |    ep_rew_mean      | 35.6     |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 15431    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53       |
# |    ep_rew_mean      | 35.5     |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 15371    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 15345    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 15340    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.2     |
# |    ep_rew_mean      | 36       |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 15317    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.9     |
# |    ep_rew_mean      | 36.2     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 15348    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.3     |
# |    ep_rew_mean      | 36.4     |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 15380    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54       |
# |    ep_rew_mean      | 36.4     |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 15338    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.4     |
# |    ep_rew_mean      | 36.7     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 15260    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.9     |
# |    ep_rew_mean      | 36.2     |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 14253    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.9     |
# |    ep_rew_mean      | 36.1     |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 14107    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54       |
# |    ep_rew_mean      | 36       |
# |    exploration_rate | 0.219    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 14080    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.4     |
# |    ep_rew_mean      | 36.3     |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 14055    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.6     |
# |    ep_rew_mean      | 36       |
# |    exploration_rate | 0.18     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 14038    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.8     |
# |    ep_rew_mean      | 35.6     |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 14017    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.9     |
# |    ep_rew_mean      | 34.7     |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 14003    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.6     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 13986    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.11     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 13990    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.5     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.0889   |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 13965    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.4     |
# |    ep_rew_mean      | 33.9     |
# |    exploration_rate | 0.0703   |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 13964    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9786     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.6     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 13916    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 34.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 13948    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.9     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 13955    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52       |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 13939    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 13958    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 13969    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 33.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 13968    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.8     |
# |    ep_rew_mean      | 33       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 13972    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.8     |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 13981    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 14008    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.5     |
# |    ep_rew_mean      | 33.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 14027    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 14027    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.4     |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 14023    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.4     |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 14034    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 32.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 14041    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.3     |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 14046    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.1     |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 14053    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 14073    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 14072    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 33.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 14095    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52       |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 14113    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 34       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 14107    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52       |
# |    ep_rew_mean      | 34.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 14125    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 14136    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 14127    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.2     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 14134    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15221    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 33.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 14154    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 14168    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 14169    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 14176    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.8     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 14181    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 32.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 14175    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 14185    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.7     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 14214    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 34       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 14223    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.5     |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 14158    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 14090    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.2     |
# |    ep_rew_mean      | 34.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 14031    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.7     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 14029    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 34.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 14020    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.3     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 14015    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18275    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 35       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 14020    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 34.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 14014    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 34.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 14017    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 14020    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.1     |
# |    ep_rew_mean      | 34       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 13997    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.9     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 13998    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.9     |
# |    ep_rew_mean      | 34.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 14016    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.7     |
# |    ep_rew_mean      | 34.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 14002    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 14014    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.9     |
# |    ep_rew_mean      | 34.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 14029    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.1     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 14031    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.2     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 14030    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.7     |
# |    ep_rew_mean      | 34.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 14029    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 21108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.5     |
# |    ep_rew_mean      | 34.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 14036    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 21308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.7     |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 14048    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 21587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 14050    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 21758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54       |
# |    ep_rew_mean      | 35.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 14050    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 22052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.4     |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 14062    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 22269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.5     |
# |    ep_rew_mean      | 35.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 14065    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 22477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.3     |
# |    ep_rew_mean      | 35.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 14076    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 22776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.1     |
# |    ep_rew_mean      | 36.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 14001    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.6     |
# |    ep_rew_mean      | 35.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 13981    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.2     |
# |    ep_rew_mean      | 35.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 13992    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.6     |
# |    ep_rew_mean      | 35.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 13993    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.8     |
# |    ep_rew_mean      | 35.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 13982    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.3     |
# |    ep_rew_mean      | 35.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 13984    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.2     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 13984    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 24146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.5     |
# |    ep_rew_mean      | 35.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 13975    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 24284    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.5     |
# |    ep_rew_mean      | 35.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 13982    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 24499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.4     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 13995    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 24766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.3     |
# |    ep_rew_mean      | 35.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 13991    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 24983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.3     |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 13999    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 25193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.5     |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 13995    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 25411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.4     |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 14003    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 25636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52.7     |
# |    ep_rew_mean      | 35       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 14007    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 25783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.4     |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 14013    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 26017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 36       |
# ...
# |    fps              | 2686     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 94081    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.9e-05  |
# |    n_updates        | 11020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.6     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 2683     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 94217    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000389 |
# |    n_updates        | 11054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.6     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 2679     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 94350    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000975 |
# |    n_updates        | 11087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 2675     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 94521    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00182  |
# |    n_updates        | 11130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.3     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 2669     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 94776    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000593 |
# |    n_updates        | 11193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2056     |
# |    fps              | 2663     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 94996    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00079  |
# |    n_updates        | 11248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 28.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 2660     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 95130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000429 |
# |    n_updates        | 11282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.2     |
# |    ep_rew_mean      | 28.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2064     |
# |    fps              | 2654     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 95370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0025   |
# |    n_updates        | 11342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 2650     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 95542    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000724 |
# |    n_updates        | 11385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.8     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 2645     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 95761    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000596 |
# |    n_updates        | 11440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.8     |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 2640     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 95940    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000475 |
# |    n_updates        | 11484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.9     |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 2635     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96140    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 11534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.7     |
# |    ep_rew_mean      | 31.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 2627     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96469    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000444 |
# |    n_updates        | 11617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.2     |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 2621     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 96755    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 11688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.2     |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 2618     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 96883    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00195  |
# |    n_updates        | 11720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.8     |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 2612     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 97144    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000737 |
# |    n_updates        | 11785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.1     |
# |    ep_rew_mean      | 32.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 2608     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 97341    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00241  |
# |    n_updates        | 11835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.2     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 2604     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 97533    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00495  |
# |    n_updates        | 11883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.8     |
# |    ep_rew_mean      | 33.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 2598     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 97797    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000472 |
# |    n_updates        | 11949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.3     |
# |    ep_rew_mean      | 33.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 2593     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98002    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000236 |
# |    n_updates        | 12000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.4     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2116     |
# |    fps              | 2589     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 98204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00517  |
# |    n_updates        | 12050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 2585     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 98382    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000858 |
# |    n_updates        | 12095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.2     |
# |    ep_rew_mean      | 34.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2124     |
# |    fps              | 2582     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 98523    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000345 |
# |    n_updates        | 12130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.3     |
# |    ep_rew_mean      | 34.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2128     |
# |    fps              | 2578     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 98737    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000642 |
# |    n_updates        | 12184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.6     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2132     |
# |    fps              | 2575     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 98901    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00038  |
# |    n_updates        | 12225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 34.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2136     |
# |    fps              | 2568     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 99173    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0843   |
# |    n_updates        | 12293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.9     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 2564     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 99302    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000745 |
# |    n_updates        | 12325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 34.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 2559     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 99471    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00881  |
# |    n_updates        | 12367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.6     |
# |    ep_rew_mean      | 35.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2148     |
# |    fps              | 2554     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 99677    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00339  |
# |    n_updates        | 12419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.6     |
# |    ep_rew_mean      | 34.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 2551     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 99841    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 12460    |
# ----------------------------------
# C:\Users\NOTEBO~1\AppData\Local\Temp/ipykernel_31748/552657337.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   obs = obs.astype(np.float)

# %%
x_ball = []
for observation in obs_list: 
   x =  observation[1]
   x_ball.append(x)

# %%
plt.plot(x_ball)
plt.xlabel("Episode")
plt.ylabel("Ball Postion")
plt.title("DQN ball position control")
# Out:
# Text(0.5, 1.0, 'DQN ball position control')

# %%
import sys
import os
import gym
import torch
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import SAC

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
sys.path.append('ballbeam-gym')
from ballbeam_gym.envs.setpoint import BallBeamSetpointEnv


kwargs = {'timestep': 0.05, 
          'setpoint': 3,
          'beam_length': 5.0,
          'max_angle': 0.2,
          'init_velocity': 0.0,
          'action_mode': 'continuous'}

env = BallBeamSetpointEnv(**kwargs)

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000, log_interval=4)

obs = env.reset()
obs_list = []
for ep in range(1000):
    obs = obs.astype(np.float)
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    obs_list.append(obs)
    #env.render()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 68       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 78       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 396      |
# | train/             |          |
# |    actor_loss      | -3.64    |
# |    critic_loss     | 0.149    |
# |    ent_coef        | 0.916    |
# |    ent_coef_loss   | -0.148   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 295      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 71.8     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 67       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 792      |
# | train/             |          |
# |    actor_loss      | -5.81    |
# |    critic_loss     | 0.0723   |
# |    ent_coef        | 0.813    |
# |    ent_coef_loss   | -0.346   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 691      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 74.2     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 63       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1188     |
# | train/             |          |
# |    actor_loss      | -8.02    |
# |    critic_loss     | 0.25     |
# |    ent_coef        | 0.722    |
# |    ent_coef_loss   | -0.543   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1087     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 75       |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 61       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1584     |
# | train/             |          |
# |    actor_loss      | -9.79    |
# |    critic_loss     | 0.375    |
# |    ent_coef        | 0.642    |
# |    ent_coef_loss   | -0.742   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1483     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 74.4     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 58       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 1980     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.653    |
# |    ent_coef        | 0.57     |
# |    ent_coef_loss   | -0.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1879     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 75.8     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 56       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2376     |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.551    |
# |    ent_coef        | 0.507    |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2275     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 75       |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 55       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 2772     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 3.42     |
# |    ent_coef        | 0.451    |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2671     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 54       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 3168     |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.401    |
# |    ent_coef_loss   | -1.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3067     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 77.5     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 53       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 3564     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 4.84     |
# |    ent_coef        | 0.357    |
# |    ent_coef_loss   | -1.57    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3463     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 78.4     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 53       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 3960     |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 2.94     |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -1.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3859     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 79.3     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 53       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 4356     |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 3.21     |
# |    ent_coef        | 0.284    |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4255     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 79.9     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 52       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 4752     |
# | train/             |          |
# |    actor_loss      | -21.8    |
# |    critic_loss     | 0.124    |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | -2.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4651     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 80.3     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 52       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 5148     |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 3.73     |
# |    ent_coef        | 0.228    |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5047     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 80.4     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 52       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 5544     |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 2.24     |
# |    ent_coef        | 0.204    |
# |    ent_coef_loss   | -1.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5443     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 80.2     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 52       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 5939     |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 5.87     |
# |    ent_coef        | 0.184    |
# |    ent_coef_loss   | -2.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5838     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.9     |
# |    ep_rew_mean     | 80       |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 52       |
# |    time_elapsed    | 120      |
# |    total_timesteps | 6331     |
# | train/             |          |
# |    actor_loss      | -25.8    |
# |    critic_loss     | 0.275    |
# |    ent_coef        | 0.166    |
# |    ent_coef_loss   | -1.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6230     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.8     |
# |    ep_rew_mean     | 79.8     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 52       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 6721     |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 6.83     |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6620     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.8     |
# |    ep_rew_mean     | 79.6     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 52       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 7110     |
# | train/             |          |
# |    actor_loss      | -26.7    |
# |    critic_loss     | 3.46     |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -2.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7009     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.7     |
# |    ep_rew_mean     | 79.4     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 51       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 7502     |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.6     |
# |    ep_rew_mean     | 79.1     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 51       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 7886     |
# | train/             |          |
# |    actor_loss      | -28.3    |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -1.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7785     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.5     |
# |    ep_rew_mean     | 78.9     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 51       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 8271     |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -2.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8170     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.4     |
# |    ep_rew_mean     | 78.8     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 50       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 8661     |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | -2.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8560     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.4     |
# |    ep_rew_mean     | 78.7     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 50       |
# |    time_elapsed    | 179      |
# |    total_timesteps | 9053     |
# | train/             |          |
# |    actor_loss      | -28.6    |
# |    critic_loss     | 9.85     |
# |    ent_coef        | 0.0853   |
# |    ent_coef_loss   | -2.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8952     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.4     |
# |    ep_rew_mean     | 78.7     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 50       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 9449     |
# | train/             |          |
# |    actor_loss      | -29.7    |
# |    critic_loss     | 0.714    |
# |    ent_coef        | 0.0769   |
# |    ent_coef_loss   | -2.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9348     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.5     |
# |    ep_rew_mean     | 78.8     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 49       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 9845     |
# | train/             |          |
# |    actor_loss      | -29.9    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.0693   |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9744     |
# ---------------------------------
# C:\Users\NOTEBO~1\AppData\Local\Temp/ipykernel_31748/2597476634.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   obs = obs.astype(np.float)

# %%
x_ball = []
for observation in obs_list: 
   x =  observation[1]
   x_ball.append(x)

# %%
plt.plot(x_ball)
plt.xlabel("Episode")
plt.ylabel("Ball Postion")
plt.title("DQN ball position control")
# Out:
# Text(0.5, 1.0, 'DQN ball position control')
